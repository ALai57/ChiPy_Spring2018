# %% [markdown]
# #  FLASK API
#     ## UNDERSTAND HOW FLASK WORKS
#     ## WHAT DOES THE WEB UI look like?

# %%
import plotly.plotly as py
import pandas as pd

# %%
df = pd.read_csv('../data/raw/CPS_School_Locations_SY1516.csv')
df['type'] = 'scattergeo'
df['locationmode'] = 'USA-states'
df['lon'] = df['Long']
df['lat'] = df['Lat']
df['name'] = df['Short_Name']
df.head()
# Out:
#                   Short_Name  School_ID  \
# 0         GLOBAL CITIZENSHIP     400009
# 1                ACE TECH HS     400010
# 2                    LOCKE A     400011
# 3                 AMANDLA HS     400012
# 4  ASPIRA - EARLY COLLEGE HS     400013
#
#                                        the_geom              Address    Zip  \
# 0   POINT (-87.7400974361456 41.80757850716726)       4647 W 47th St  60632
# 1   POINT (-87.6258490370775 41.79612150915272)      5410 S State St  60609
# 2  POINT (-87.70523452626735 41.87724835217878)  3141 W Jackson Blvd  60612
# 3  POINT (-87.63547156927478 41.77080225409796)   6800 S Stewart Ave  60621
# 4  POINT (-87.72709565821633 41.93729828458827)     3986 W Barry Ave  60618
#
#          Lat       Long  Network Governance Grade_Cat  \
# 0  41.807579 -87.740097  Charter    Charter        ES
# 1  41.796122 -87.625849  Charter    Charter        HS
# 2  41.877248 -87.705235  Charter    Charter        ES
# 3  41.770802 -87.635472  Charter    Charter        HS
# 4  41.937298 -87.727096  Charter    Charter        HS
#
#              ...                            Phone GeoNetwork  \
# 0            ...                   1(773)582-1100          8
# 1            ...                   1(773)548-8705          9
# 2            ...                   1(773)265-7232          5
# 3            ...                   1(773)535-7150         11
# 4            ...              1(773)252-0970 x137          4
#
#              COMMAREA WARD_15              ALD_15        type locationmode  \
# 0      GARFIELD RIDGE      14     Edward M. Burke  scattergeo   USA-states
# 1     WASHINGTON PARK       3  Patricia R. Dowell  scattergeo   USA-states
# 2  EAST GARFIELD PARK      28      Jason C. Ervin  scattergeo   USA-states
# 3           ENGLEWOOD       6  Roderick T. Sawyer  scattergeo   USA-states
# 4            AVONDALE      30   Ariel E. Reboyras  scattergeo   USA-states
#
#          lon        lat                       name
# 0 -87.740097  41.807579         GLOBAL CITIZENSHIP
# 1 -87.625849  41.796122                ACE TECH HS
# 2 -87.705235  41.877248                    LOCKE A
# 3 -87.635472  41.770802                 AMANDLA HS
# 4 -87.727096  41.937298  ASPIRA - EARLY COLLEGE HS
#
# [5 rows x 21 columns]

# %%
data = df.loc[:,['type','locationmode','lon','lat','name']].to_dict(orient='records')
display(data)
# Out:
# [{'lat': 41.807579,
#   'locationmode': 'USA-states',
#   'lon': -87.74009699999999,
#   'name': 'GLOBAL CITIZENSHIP',
#   'type': 'scattergeo'},
#  {'lat': 41.796122,
#   'locationmode': 'USA-states',
#   'lon': -87.625849,
#   'name': 'ACE TECH HS',
#   'type': 'scattergeo'},
#  {'lat': 41.877248,
#   'locationmode': 'USA-states',
#   'lon': -87.705235,
#   'name': 'LOCKE A',
#   'type': 'scattergeo'},
#  {'lat': 41.770802,
#   'locationmode': 'USA-states',
#   'lon': -87.635472,
#   'name': 'AMANDLA HS',
#   'type': 'scattergeo'},
#  {'lat': 41.937298,
#   'locationmode': 'USA-states',
#   'lon': -87.727096,
#   'name': 'ASPIRA - EARLY COLLEGE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.966406,
#   'locationmode': 'USA-states',
#   'lon': -87.721825,
#   'name': 'ASPIRA - HAUGAN',
#   'type': 'scattergeo'},
#  {'lat': 41.884205,
#   'locationmode': 'USA-states',
#   'lon': -87.761891,
#   'name': 'AUSTIN BUS & ENTRP HS',
#   'type': 'scattergeo'},
#  {'lat': 41.819277,
#   'locationmode': 'USA-states',
#   'lon': -87.626622,
#   'name': 'BRONZEVILLE LIGHTHOUSE',
#   'type': 'scattergeo'},
#  {'lat': 41.882321999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.765322,
#   'name': 'CATALYST - CIRCLE ROCK',
#   'type': 'scattergeo'},
#  {'lat': 41.899377,
#   'locationmode': 'USA-states',
#   'lon': -87.69494499999999,
#   'name': 'CHICAGO ARTS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.743179,
#   'locationmode': 'USA-states',
#   'lon': -87.587928,
#   'name': 'CICS - AVALON/SOUTH SHORE',
#   'type': 'scattergeo'},
#  {'lat': 41.794043,
#   'locationmode': 'USA-states',
#   'lon': -87.670243,
#   'name': 'CICS - BASIL',
#   'type': 'scattergeo'},
#  {'lat': 41.922415,
#   'locationmode': 'USA-states',
#   'lon': -87.68135799999999,
#   'name': 'CICS - BUCKTOWN',
#   'type': 'scattergeo'},
#  {'lat': 41.720246,
#   'locationmode': 'USA-states',
#   'lon': -87.657561,
#   'name': 'CICS - LOOMIS',
#   'type': 'scattergeo'},
#  {'lat': 41.950891,
#   'locationmode': 'USA-states',
#   'lon': -87.710492,
#   'name': 'CICS - IRVING PARK',
#   'type': 'scattergeo'},
#  {'lat': 41.684433,
#   'locationmode': 'USA-states',
#   'lon': -87.616888,
#   'name': 'CICS - PRAIRIE',
#   'type': 'scattergeo'},
#  {'lat': 41.783617,
#   'locationmode': 'USA-states',
#   'lon': -87.622068,
#   'name': 'CICS - WASHINGTON PARK',
#   'type': 'scattergeo'},
#  {'lat': 41.921687,
#   'locationmode': 'USA-states',
#   'lon': -87.776749,
#   'name': 'CICS - WEST BELDEN',
#   'type': 'scattergeo'},
#  {'lat': 41.745365,
#   'locationmode': 'USA-states',
#   'lon': -87.692614,
#   'name': 'CICS - WRIGHTWOOD',
#   'type': 'scattergeo'},
#  {'lat': 41.748382,
#   'locationmode': 'USA-states',
#   'lon': -87.66898,
#   'name': 'CICS - ELLISON HS',
#   'type': 'scattergeo'},
#  {'lat': 41.721221,
#   'locationmode': 'USA-states',
#   'lon': -87.65576800000001,
#   'name': 'CICS - LONGWOOD',
#   'type': 'scattergeo'},
#  {'lat': 41.990245,
#   'locationmode': 'USA-states',
#   'lon': -87.726504,
#   'name': 'CICS - NORTHTOWN HS',
#   'type': 'scattergeo'},
#  {'lat': 42.013031,
#   'locationmode': 'USA-states',
#   'lon': -87.674818,
#   'name': 'CHICAGO MATH & SCIENCE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.88055,
#   'locationmode': 'USA-states',
#   'lon': -87.649772,
#   'name': 'CHICAGO VIRTUAL',
#   'type': 'scattergeo'},
#  {'lat': 41.864952,
#   'locationmode': 'USA-states',
#   'lon': -87.725022,
#   'name': 'COMMUNITY SERVICES WEST HS',
#   'type': 'scattergeo'},
#  {'lat': 41.906771,
#   'locationmode': 'USA-states',
#   'lon': -87.69436400000001,
#   'name': 'ERIE',
#   'type': 'scattergeo'},
#  {'lat': 41.862077,
#   'locationmode': 'USA-states',
#   'lon': -87.717642,
#   'name': 'FRAZIER CHARTER',
#   'type': 'scattergeo'},
#  {'lat': 41.897313,
#   'locationmode': 'USA-states',
#   'lon': -87.721959,
#   'name': 'GALAPAGOS',
#   'type': 'scattergeo'},
#  {'lat': 41.883362,
#   'locationmode': 'USA-states',
#   'lon': -87.668077,
#   'name': 'HOPE INSTITUTE',
#   'type': 'scattergeo'},
#  {'lat': 41.85837,
#   'locationmode': 'USA-states',
#   'lon': -87.721071,
#   'name': 'KIPP - ASCEND',
#   'type': 'scattergeo'},
#  {'lat': 41.69804,
#   'locationmode': 'USA-states',
#   'lon': -87.631058,
#   'name': 'NKRUMAH',
#   'type': 'scattergeo'},
#  {'lat': 41.867273,
#   'locationmode': 'USA-states',
#   'lon': -87.710679,
#   'name': 'LEARN - BUTLER',
#   'type': 'scattergeo'},
#  {'lat': 41.877860999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.698739,
#   'name': 'LEARN - CAMPBELL',
#   'type': 'scattergeo'},
#  {'lat': 41.874687,
#   'locationmode': 'USA-states',
#   'lon': -87.68656800000001,
#   'name': 'LEARN - EXCEL',
#   'type': 'scattergeo'},
#  {'lat': 41.856859,
#   'locationmode': 'USA-states',
#   'lon': -87.73034799999999,
#   'name': 'LEGACY',
#   'type': 'scattergeo'},
#  {'lat': 41.8257,
#   'locationmode': 'USA-states',
#   'lon': -87.66772399999999,
#   'name': 'NAMASTE',
#   'type': 'scattergeo'},
#  {'lat': 41.900191,
#   'locationmode': 'USA-states',
#   'lon': -87.662628,
#   'name': 'NOBLE - NOBLE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.764083,
#   'locationmode': 'USA-states',
#   'lon': -87.601974,
#   'name': 'NOBLE - COMER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.895282,
#   'locationmode': 'USA-states',
#   'lon': -87.66448299999999,
#   'name': 'NOBLE - GOLDER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.915214,
#   'locationmode': 'USA-states',
#   'lon': -87.730127,
#   'name': 'NOBLE - PRITZKER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.892425,
#   'locationmode': 'USA-states',
#   'lon': -87.660859,
#   'name': 'NOBLE - RAUNER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.895362,
#   'locationmode': 'USA-states',
#   'lon': -87.718047,
#   'name': 'NOBLE - ROWE CLARK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.865817,
#   'locationmode': 'USA-states',
#   'lon': -87.67611099999999,
#   'name': 'NOBLE - UIC HS',
#   'type': 'scattergeo'},
#  {'lat': 41.858564,
#   'locationmode': 'USA-states',
#   'lon': -87.708987,
#   'name': 'NORTH LAWNDALE - CHRISTIANA HS',
#   'type': 'scattergeo'},
#  {'lat': 41.864146000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.700681,
#   'name': 'NORTH LAWNDALE - COLLINS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.983371000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.67116,
#   'name': 'AHS - PASSAGES',
#   'type': 'scattergeo'},
#  {'lat': 41.745961,
#   'locationmode': 'USA-states',
#   'lon': -87.652045,
#   'name': 'PERSPECTIVES - LEADERSHIP HS',
#   'type': 'scattergeo'},
#  {'lat': 41.745948999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.650657,
#   'name': 'PERSPECTIVES - TECH HS',
#   'type': 'scattergeo'},
#  {'lat': 41.855999,
#   'locationmode': 'USA-states',
#   'lon': -87.62853100000001,
#   'name': 'PERSPECTIVES - JOSLIN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.827784,
#   'locationmode': 'USA-states',
#   'lon': -87.624788,
#   'name': 'PERSPECTIVES - MATH & SCI HS',
#   'type': 'scattergeo'},
#  {'lat': 41.87276,
#   'locationmode': 'USA-states',
#   'lon': -87.76333699999999,
#   'name': 'PLATO',
#   'type': 'scattergeo'},
#  {'lat': 41.89255,
#   'locationmode': 'USA-states',
#   'lon': -87.707796,
#   'name': 'POLARIS',
#   'type': 'scattergeo'},
#  {'lat': 41.90307,
#   'locationmode': 'USA-states',
#   'lon': -87.66354100000001,
#   'name': 'PROLOGUE - EARLY COLLEGE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.775366999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.663996,
#   'name': 'PROVIDENCE ENGLEWOOD',
#   'type': 'scattergeo'},
#  {'lat': 41.752458000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.600255,
#   'name': 'SHABAZZ - SHABAZZ',
#   'type': 'scattergeo'},
#  {'lat': 41.804309,
#   'locationmode': 'USA-states',
#   'lon': -87.625015,
#   'name': 'SHABAZZ - DUSABLE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.76739,
#   'locationmode': 'USA-states',
#   'lon': -87.66763900000001,
#   'name': 'SHABAZZ - SIZEMORE',
#   'type': 'scattergeo'},
#  {'lat': 41.827726,
#   'locationmode': 'USA-states',
#   'lon': -87.608501,
#   'name': 'U OF C - DONOGHUE',
#   'type': 'scattergeo'},
#  {'lat': 41.811183,
#   'locationmode': 'USA-states',
#   'lon': -87.598786,
#   'name': 'U OF C - NKO',
#   'type': 'scattergeo'},
#  {'lat': 41.77813,
#   'locationmode': 'USA-states',
#   'lon': -87.598114,
#   'name': 'U OF C - WOODLAWN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.813547,
#   'locationmode': 'USA-states',
#   'lon': -87.608426,
#   'name': 'U OF C - WOODSON',
#   'type': 'scattergeo'},
#  {'lat': 41.810134999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.73049499999999,
#   'name': 'UNO - ZIZUMBO',
#   'type': 'scattergeo'},
#  {'lat': 41.8082,
#   'locationmode': 'USA-states',
#   'lon': -87.73045,
#   'name': 'UNO - TORRES',
#   'type': 'scattergeo'},
#  {'lat': 41.859504,
#   'locationmode': 'USA-states',
#   'lon': -87.667949,
#   'name': 'UNO - DE LAS CASAS',
#   'type': 'scattergeo'},
#  {'lat': 41.937476000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.69959399999999,
#   'name': 'UNO - FUENTES',
#   'type': 'scattergeo'},
#  {'lat': 41.850035,
#   'locationmode': 'USA-states',
#   'lon': -87.692551,
#   'name': 'UNO - PAZ',
#   'type': 'scattergeo'},
#  {'lat': 41.799929999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.693862,
#   'name': 'UNO - TAMAYO',
#   'type': 'scattergeo'},
#  {'lat': 41.809171,
#   'locationmode': 'USA-states',
#   'lon': -87.730467,
#   'name': 'UNO - GARCIA HS',
#   'type': 'scattergeo'},
#  {'lat': 41.781498,
#   'locationmode': 'USA-states',
#   'lon': -87.634357,
#   'name': 'URBAN PREP - ENGLEWOOD HS',
#   'type': 'scattergeo'},
#  {'lat': 41.844544,
#   'locationmode': 'USA-states',
#   'lon': -87.618724,
#   'name': 'YOUNG WOMENS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.808309,
#   'locationmode': 'USA-states',
#   'lon': -87.69739399999999,
#   'name': 'UNO - MARQUEZ',
#   'type': 'scattergeo'},
#  {'lat': 41.863301,
#   'locationmode': 'USA-states',
#   'lon': -87.659095,
#   'name': 'CHICAGO TECH HS',
#   'type': 'scattergeo'},
#  {'lat': 41.653663,
#   'locationmode': 'USA-states',
#   'lon': -87.605039,
#   'name': 'CICS - BOND',
#   'type': 'scattergeo'},
#  {'lat': 41.744849,
#   'locationmode': 'USA-states',
#   'lon': -87.55022199999999,
#   'name': 'EPIC HS',
#   'type': 'scattergeo'},
#  {'lat': 41.907796999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.66407199999999,
#   'name': 'ROWE',
#   'type': 'scattergeo'},
#  {'lat': 41.878809000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.678195,
#   'name': 'NOBLE - BULLS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.882740000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.626338,
#   'name': 'NOBLE - MUCHIN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.822884,
#   'locationmode': 'USA-states',
#   'lon': -87.693996,
#   'name': 'UNO - CISNEROS',
#   'type': 'scattergeo'},
#  {'lat': 41.86254,
#   'locationmode': 'USA-states',
#   'lon': -87.660107,
#   'name': 'URBAN PREP - WEST HS',
#   'type': 'scattergeo'},
#  {'lat': 41.845967,
#   'locationmode': 'USA-states',
#   'lon': -87.68724,
#   'name': 'INSTITUTO - HEALTH',
#   'type': 'scattergeo'},
#  {'lat': 41.831118,
#   'locationmode': 'USA-states',
#   'lon': -87.613629,
#   'name': 'URBAN PREP - BRONZEVILLE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.778369,
#   'locationmode': 'USA-states',
#   'lon': -87.63511700000001,
#   'name': 'NOBLE - JOHNSON HS',
#   'type': 'scattergeo'},
#  {'lat': 41.733333,
#   'locationmode': 'USA-states',
#   'lon': -87.54558,
#   'name': 'LEARN - SOUTH CHICAGO',
#   'type': 'scattergeo'},
#  {'lat': 41.653141,
#   'locationmode': 'USA-states',
#   'lon': -87.601873,
#   'name': 'CICS - HAWKINS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.721136,
#   'locationmode': 'USA-states',
#   'lon': -87.66241600000001,
#   'name': 'PROLOGUE - JOHNSTON HS',
#   'type': 'scattergeo'},
#  {'lat': 41.743122,
#   'locationmode': 'USA-states',
#   'lon': -87.66572099999999,
#   'name': 'LEARN - PERKINS',
#   'type': 'scattergeo'},
#  {'lat': 41.801041999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.708797,
#   'name': 'UNO - SOCCER ELEM',
#   'type': 'scattergeo'},
#  {'lat': 41.907796999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.645561,
#   'name': 'CICS - CHICAGOQUEST HS',
#   'type': 'scattergeo'},
#  {'lat': 41.900344,
#   'locationmode': 'USA-states',
#   'lon': -87.68989599999999,
#   'name': 'UNO - SANTIAGO',
#   'type': 'scattergeo'},
#  {'lat': 41.770992,
#   'locationmode': 'USA-states',
#   'lon': -87.693075,
#   'name': 'CATALYST - MARIA',
#   'type': 'scattergeo'},
#  {'lat': 41.774572,
#   'locationmode': 'USA-states',
#   'lon': -87.676147,
#   'name': 'MONTESSORI ENGLEWOOD',
#   'type': 'scattergeo'},
#  {'lat': 41.734442,
#   'locationmode': 'USA-states',
#   'lon': -87.650987,
#   'name': 'NOBLE - HANSBERRY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.869328,
#   'locationmode': 'USA-states',
#   'lon': -87.71165400000001,
#   'name': 'NOBLE - DRW HS',
#   'type': 'scattergeo'},
#  {'lat': 41.881733000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.733778,
#   'name': 'LEGAL PREP HS',
#   'type': 'scattergeo'},
#  {'lat': 41.917952,
#   'locationmode': 'USA-states',
#   'lon': -87.78783,
#   'name': 'UNO - CLEMENTE',
#   'type': 'scattergeo'},
#  {'lat': 42.016476000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.68440600000001,
#   'name': 'UNO - ROGERS PARK',
#   'type': 'scattergeo'},
#  {'lat': 41.880447,
#   'locationmode': 'USA-states',
#   'lon': -87.74253900000001,
#   'name': 'YCCS - SCHOLASTIC ACHIEVEMENT',
#   'type': 'scattergeo'},
#  {'lat': 41.841331,
#   'locationmode': 'USA-states',
#   'lon': -87.625331,
#   'name': 'YCCS - MCKINLEY',
#   'type': 'scattergeo'},
#  {'lat': 41.938187,
#   'locationmode': 'USA-states',
#   'lon': -87.727137,
#   'name': 'YCCS - ASPIRA PANTOJA',
#   'type': 'scattergeo'},
#  {'lat': 41.901571999999994,
#   'locationmode': 'USA-states',
#   'lon': -87.70685999999999,
#   'name': 'YCCS - ASSOCIATION HOUSE',
#   'type': 'scattergeo'},
#  {'lat': 41.894976,
#   'locationmode': 'USA-states',
#   'lon': -87.760221,
#   'name': 'YCCS - AUSTIN CAREER',
#   'type': 'scattergeo'},
#  {'lat': 41.864943,
#   'locationmode': 'USA-states',
#   'lon': -87.723662,
#   'name': 'YCCS - CCA ACADEMY',
#   'type': 'scattergeo'},
#  {'lat': 41.773962,
#   'locationmode': 'USA-states',
#   'lon': -87.61574,
#   'name': 'YCCS - HOUSTON',
#   'type': 'scattergeo'},
#  {'lat': 41.751377000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.64173100000001,
#   'name': 'YCCS - YOUTH DEVELOPMENT',
#   'type': 'scattergeo'},
#  {'lat': 41.90285,
#   'locationmode': 'USA-states',
#   'lon': -87.69600600000001,
#   'name': 'YCCS - CAMPOS',
#   'type': 'scattergeo'},
#  {'lat': 41.883047,
#   'locationmode': 'USA-states',
#   'lon': -87.627734,
#   'name': 'YCCS - INNOVATIONS',
#   'type': 'scattergeo'},
#  {'lat': 41.857208,
#   'locationmode': 'USA-states',
#   'lon': -87.644888,
#   'name': 'YCCS - ADDAMS',
#   'type': 'scattergeo'},
#  {'lat': 41.854665000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.69543,
#   'name': 'YCCS - LATINO YOUTH',
#   'type': 'scattergeo'},
#  {'lat': 41.712922,
#   'locationmode': 'USA-states',
#   'lon': -87.592333,
#   'name': 'YCCS - OLIVE HARVEY',
#   'type': 'scattergeo'},
#  {'lat': 41.809695,
#   'locationmode': 'USA-states',
#   'lon': -87.59934,
#   'name': 'LITTLE BLACK PEARL HS',
#   'type': 'scattergeo'},
#  {'lat': 41.746287,
#   'locationmode': 'USA-states',
#   'lon': -87.578492,
#   'name': 'YCCS - SULLIVAN',
#   'type': 'scattergeo'},
#  {'lat': 41.965295000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.659239,
#   'name': 'YCCS - TRUMAN',
#   'type': 'scattergeo'},
#  {'lat': 41.876317,
#   'locationmode': 'USA-states',
#   'lon': -87.674138,
#   'name': 'YCCS - VIRTUAL',
#   'type': 'scattergeo'},
#  {'lat': 41.890803000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.702053,
#   'name': 'YCCS - WEST TOWN',
#   'type': 'scattergeo'},
#  {'lat': 41.90224,
#   'locationmode': 'USA-states',
#   'lon': -87.74880999999999,
#   'name': 'YCCS - WESTSIDE HOLISTIC',
#   'type': 'scattergeo'},
#  {'lat': 41.832072,
#   'locationmode': 'USA-states',
#   'lon': -87.62678100000001,
#   'name': 'YCCS - YOUTH CONNECTION',
#   'type': 'scattergeo'},
#  {'lat': 41.891816,
#   'locationmode': 'USA-states',
#   'lon': -87.74661400000001,
#   'name': 'KIPP CHICAGO - CREATE',
#   'type': 'scattergeo'},
#  {'lat': 41.691953000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.654248,
#   'name': 'CAMELOT - CHICAGO EXCEL HS',
#   'type': 'scattergeo'},
#  {'lat': 41.845446,
#   'locationmode': 'USA-states',
#   'lon': -87.684065,
#   'name': 'INSTITUTO - LOZANO HS',
#   'type': 'scattergeo'},
#  {'lat': 41.801762,
#   'locationmode': 'USA-states',
#   'lon': -87.711025,
#   'name': 'UNO - SOCCER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.730131,
#   'locationmode': 'USA-states',
#   'lon': -87.60698000000001,
#   'name': 'YCCS - CHATHAM',
#   'type': 'scattergeo'},
#  {'lat': 41.887409999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.701397,
#   'name': 'LEARN - 7',
#   'type': 'scattergeo'},
#  {'lat': 41.813109000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.693238,
#   'name': 'UNO - BRIGHTON PARK',
#   'type': 'scattergeo'},
#  {'lat': 41.706666999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.60257299999999,
#   'name': 'NOBLE - BUTLER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.734621999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.556201,
#   'name': 'NOBLE - BAKER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.922181,
#   'locationmode': 'USA-states',
#   'lon': -87.757522,
#   'name': 'CHRISTOPHER HOUSE',
#   'type': 'scattergeo'},
#  {'lat': 41.679318,
#   'locationmode': 'USA-states',
#   'lon': -87.617968,
#   'name': 'CHICAGO COLLEGIATE',
#   'type': 'scattergeo'},
#  {'lat': 41.938988,
#   'locationmode': 'USA-states',
#   'lon': -87.741129,
#   'name': 'INTRINSIC HS',
#   'type': 'scattergeo'},
#  {'lat': 41.793556,
#   'locationmode': 'USA-states',
#   'lon': -87.639967,
#   'name': 'KIPP CHICAGO - BLOOM',
#   'type': 'scattergeo'},
#  {'lat': 41.845957,
#   'locationmode': 'USA-states',
#   'lon': -87.685903,
#   'name': 'INSTITUTO - LOZANO MASTERY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.887413,
#   'locationmode': 'USA-states',
#   'lon': -87.702704,
#   'name': 'LEARN - MIDDLE',
#   'type': 'scattergeo'},
#  {'lat': 41.795201,
#   'locationmode': 'USA-states',
#   'lon': -87.683963,
#   'name': 'HORIZON - SOUTHWEST',
#   'type': 'scattergeo'},
#  {'lat': 41.92563,
#   'locationmode': 'USA-states',
#   'lon': -87.769808,
#   'name': 'NOBLE - ITW SPEER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.906878999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.645577,
#   'name': 'NOBLE - ACADEMY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.694671,
#   'locationmode': 'USA-states',
#   'lon': -87.65353499999999,
#   'name': 'FOUNDATIONS',
#   'type': 'scattergeo'},
#  {'lat': 41.808226,
#   'locationmode': 'USA-states',
#   'lon': -87.70264499999999,
#   'name': 'PATHWAYS - BRIGHTON PARK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.759749,
#   'locationmode': 'USA-states',
#   'lon': -87.556487,
#   'name': 'CAMELOT - EXCEL WOODLAWN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.765929,
#   'locationmode': 'USA-states',
#   'lon': -87.69073,
#   'name': 'CAMELOT - EXCEL SOUTHWEST HS',
#   'type': 'scattergeo'},
#  {'lat': 41.861174,
#   'locationmode': 'USA-states',
#   'lon': -87.709287,
#   'name': 'KIPP CHICAGO - ASCEND PRIMARY',
#   'type': 'scattergeo'},
#  {'lat': 41.737173999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.573268,
#   'name': 'CHICAGO VOCATIONAL HS',
#   'type': 'scattergeo'},
#  {'lat': 41.840226,
#   'locationmode': 'USA-states',
#   'lon': -87.617637,
#   'name': 'DUNBAR HS',
#   'type': 'scattergeo'},
#  {'lat': 41.873065999999994,
#   'locationmode': 'USA-states',
#   'lon': -87.627675,
#   'name': 'JONES HS',
#   'type': 'scattergeo'},
#  {'lat': 41.920059,
#   'locationmode': 'USA-states',
#   'lon': -87.761048,
#   'name': 'PROSSER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.901575,
#   'locationmode': 'USA-states',
#   'lon': -87.635385,
#   'name': 'PAYTON HS',
#   'type': 'scattergeo'},
#  {'lat': 41.802881,
#   'locationmode': 'USA-states',
#   'lon': -87.662278,
#   'name': 'RICHARDS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.911674,
#   'locationmode': 'USA-states',
#   'lon': -87.735238,
#   'name': 'NORTH-GRAND HS',
#   'type': 'scattergeo'},
#  {'lat': 41.745781,
#   'locationmode': 'USA-states',
#   'lon': -87.63541,
#   'name': 'SIMEON HS',
#   'type': 'scattergeo'},
#  {'lat': 41.889977,
#   'locationmode': 'USA-states',
#   'lon': -87.707332,
#   'name': 'WESTINGHOUSE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.791464000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.72447,
#   'name': 'HANCOCK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.975066999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.679484,
#   'name': 'AMUNDSEN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.749376,
#   'locationmode': 'USA-states',
#   'lon': -87.721097,
#   'name': 'BOGAN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.84856,
#   'locationmode': 'USA-states',
#   'lon': -87.708706,
#   'name': 'FARRAGUT HS',
#   'type': 'scattergeo'},
#  {'lat': 41.689951,
#   'locationmode': 'USA-states',
#   'lon': -87.63757199999999,
#   'name': 'FENGER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.769714,
#   'locationmode': 'USA-states',
#   'lon': -87.637153,
#   'name': 'ROBESON HS',
#   'type': 'scattergeo'},
#  {'lat': 41.939797,
#   'locationmode': 'USA-states',
#   'lon': -87.75416700000001,
#   'name': 'FOREMAN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.791013,
#   'locationmode': 'USA-states',
#   'lon': -87.68895400000001,
#   'name': 'GAGE PARK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.718371999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.620623,
#   'name': 'HARLAN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.775124,
#   'locationmode': 'USA-states',
#   'lon': -87.669089,
#   'name': 'HARPER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.753748,
#   'locationmode': 'USA-states',
#   'lon': -87.601727,
#   'name': 'HIRSCH HS',
#   'type': 'scattergeo'},
#  {'lat': 41.782257,
#   'locationmode': 'USA-states',
#   'lon': -87.58661500000001,
#   'name': 'HYDE PARK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.818729,
#   'locationmode': 'USA-states',
#   'lon': -87.694639,
#   'name': 'KELLY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.927918,
#   'locationmode': 'USA-states',
#   'lon': -87.73599899999999,
#   'name': 'KELVYN PARK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.789961,
#   'locationmode': 'USA-states',
#   'lon': -87.78084,
#   'name': 'KENNEDY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.954764000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.668953,
#   'name': 'LAKE VIEW HS',
#   'type': 'scattergeo'},
#  {'lat': 41.946645000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.691013,
#   'name': 'LANE TECH HS',
#   'type': 'scattergeo'},
#  {'lat': 41.870939,
#   'locationmode': 'USA-states',
#   'lon': -87.699896,
#   'name': 'MANLEY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.878444,
#   'locationmode': 'USA-states',
#   'lon': -87.70805,
#   'name': 'MARSHALL HS',
#   'type': 'scattergeo'},
#  {'lat': 41.987589,
#   'locationmode': 'USA-states',
#   'lon': -87.702496,
#   'name': 'MATHER HS',
#   'type': 'scattergeo'},
#  {'lat': 41.692035,
#   'locationmode': 'USA-states',
#   'lon': -87.665658,
#   'name': 'MORGAN PARK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.692763,
#   'locationmode': 'USA-states',
#   'lon': -87.616353,
#   'name': 'BROOKS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.823879999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.619796,
#   'name': 'PHILLIPS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.964828000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.71481899999999,
#   'name': 'ROOSEVELT HS',
#   'type': 'scattergeo'},
#  {'lat': 41.946365,
#   'locationmode': 'USA-states',
#   'lon': -87.735612,
#   'name': 'SCHURZ HS',
#   'type': 'scattergeo'},
#  {'lat': 41.989028999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.667136,
#   'name': 'SENN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.935634,
#   'locationmode': 'USA-states',
#   'lon': -87.78351500000001,
#   'name': 'STEINMETZ HS',
#   'type': 'scattergeo'},
#  {'lat': 42.002688,
#   'locationmode': 'USA-states',
#   'lon': -87.66919200000001,
#   'name': 'SULLIVAN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.982960999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.791547,
#   'name': 'TAFT HS',
#   'type': 'scattergeo'},
#  {'lat': 41.80751,
#   'locationmode': 'USA-states',
#   'lon': -87.642966,
#   'name': 'TILDEN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.973185,
#   'locationmode': 'USA-states',
#   'lon': -87.713386,
#   'name': 'VON STEUBEN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.918268,
#   'locationmode': 'USA-states',
#   'lon': -87.64600899999999,
#   'name': 'LINCOLN PARK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.688137,
#   'locationmode': 'USA-states',
#   'lon': -87.53757,
#   'name': 'WASHINGTON HS',
#   'type': 'scattergeo'},
#  {'lat': 41.898995,
#   'locationmode': 'USA-states',
#   'lon': -87.66748299999999,
#   'name': 'WELLS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.780526,
#   'locationmode': 'USA-states',
#   'lon': -87.718014,
#   'name': 'HUBBARD HS',
#   'type': 'scattergeo'},
#  {'lat': 41.982973,
#   'locationmode': 'USA-states',
#   'lon': -87.722386,
#   'name': 'NORTHSIDE LEARNING HS',
#   'type': 'scattergeo'},
#  {'lat': 41.759852,
#   'locationmode': 'USA-states',
#   'lon': -87.675947,
#   'name': 'SOUTHSIDE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.803771999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.59042099999999,
#   'name': 'KENWOOD HS',
#   'type': 'scattergeo'},
#  {'lat': 41.842533,
#   'locationmode': 'USA-states',
#   'lon': -87.695261,
#   'name': 'YORK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.981315,
#   'locationmode': 'USA-states',
#   'lon': -87.708708,
#   'name': 'NORTHSIDE PREP HS',
#   'type': 'scattergeo'},
#  {'lat': 41.864365,
#   'locationmode': 'USA-states',
#   'lon': -87.668722,
#   'name': 'SIMPSON HS',
#   'type': 'scattergeo'},
#  {'lat': 41.813675,
#   'locationmode': 'USA-states',
#   'lon': -87.603874,
#   'name': 'KING HS',
#   'type': 'scattergeo'},
#  {'lat': 41.691221,
#   'locationmode': 'USA-states',
#   'lon': -87.71777,
#   'name': 'CHICAGO AGRICULTURE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.830555,
#   'locationmode': 'USA-states',
#   'lon': -87.61921600000001,
#   'name': 'CHICAGO MILITARY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.878603000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.664233,
#   'name': 'YOUNG HS',
#   'type': 'scattergeo'},
#  {'lat': 41.803059999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.722042,
#   'name': 'CURIE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.902626,
#   'locationmode': 'USA-states',
#   'lon': -87.68690600000001,
#   'name': 'CLEMENTE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.656290000000006,
#   'locationmode': 'USA-states',
#   'lon': -87.59062,
#   'name': 'CARVER MILITARY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.70666,
#   'locationmode': 'USA-states',
#   'lon': -87.60121600000001,
#   'name': 'CORLISS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.705859000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.653749,
#   'name': 'JULIAN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.852667,
#   'locationmode': 'USA-states',
#   'lon': -87.663732,
#   'name': 'JUAREZ HS',
#   'type': 'scattergeo'},
#  {'lat': 41.960364,
#   'locationmode': 'USA-states',
#   'lon': -87.764663,
#   'name': 'VAUGHN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.793553,
#   'locationmode': 'USA-states',
#   'lon': -87.641244,
#   'name': 'HOPE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.849675,
#   'locationmode': 'USA-states',
#   'lon': -87.625315,
#   'name': 'GRAHAM HS',
#   'type': 'scattergeo'},
#  {'lat': 41.698739,
#   'locationmode': 'USA-states',
#   'lon': -87.532976,
#   'name': 'ADDAMS',
#   'type': 'scattergeo'},
#  {'lat': 41.934126,
#   'locationmode': 'USA-states',
#   'lon': -87.65622900000001,
#   'name': 'AGASSIZ',
#   'type': 'scattergeo'},
#  {'lat': 41.833853999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.650653,
#   'name': 'ARMOUR',
#   'type': 'scattergeo'},
#  {'lat': 42.01015,
#   'locationmode': 'USA-states',
#   'lon': -87.684442,
#   'name': 'ARMSTRONG G',
#   'type': 'scattergeo'},
#  {'lat': 41.916045000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.721742,
#   'name': 'MARINE LEADERSHIP AT AMES HS',
#   'type': 'scattergeo'},
#  {'lat': 41.945062,
#   'locationmode': 'USA-states',
#   'lon': -87.68104100000001,
#   'name': 'AUDUBON',
#   'type': 'scattergeo'},
#  {'lat': 41.867832,
#   'locationmode': 'USA-states',
#   'lon': -87.680418,
#   'name': 'JEFFERSON HS',
#   'type': 'scattergeo'},
#  {'lat': 41.748247,
#   'locationmode': 'USA-states',
#   'lon': -87.591654,
#   'name': 'AVALON PARK',
#   'type': 'scattergeo'},
#  {'lat': 41.705131,
#   'locationmode': 'USA-states',
#   'lon': -87.658074,
#   'name': 'BARNARD',
#   'type': 'scattergeo'},
#  {'lat': 41.932511,
#   'locationmode': 'USA-states',
#   'lon': -87.739388,
#   'name': 'BARRY',
#   'type': 'scattergeo'},
#  {'lat': 41.754194,
#   'locationmode': 'USA-states',
#   'lon': -87.670927,
#   'name': 'BARTON',
#   'type': 'scattergeo'},
#  {'lat': 41.774246000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.653532,
#   'name': 'BASS',
#   'type': 'scattergeo'},
#  {'lat': 41.958220000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.702151,
#   'name': 'BATEMAN',
#   'type': 'scattergeo'},
#  {'lat': 41.784942,
#   'locationmode': 'USA-states',
#   'lon': -87.647453,
#   'name': 'NICHOLSON',
#   'type': 'scattergeo'},
#  {'lat': 41.971506,
#   'locationmode': 'USA-states',
#   'lon': -87.709304,
#   'name': 'EDISON',
#   'type': 'scattergeo'},
#  {'lat': 41.867813,
#   'locationmode': 'USA-states',
#   'lon': -87.770418,
#   'name': 'CLARK ES',
#   'type': 'scattergeo'},
#  {'lat': 41.972394,
#   'locationmode': 'USA-states',
#   'lon': -87.757565,
#   'name': 'BEAUBIEN',
#   'type': 'scattergeo'},
#  {'lat': 41.885321000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.705855,
#   'name': 'BEIDLER',
#   'type': 'scattergeo'},
#  {'lat': 41.958938,
#   'locationmode': 'USA-states',
#   'lon': -87.73402,
#   'name': 'BELDING',
#   'type': 'scattergeo'},
#  {'lat': 41.949529999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.686018,
#   'name': 'BELL',
#   'type': 'scattergeo'},
#  {'lat': 41.710435,
#   'locationmode': 'USA-states',
#   'lon': -87.61739,
#   'name': 'BENNETT',
#   'type': 'scattergeo'},
#  {'lat': 41.950781,
#   'locationmode': 'USA-states',
#   'lon': -87.664968,
#   'name': 'BLAINE',
#   'type': 'scattergeo'},
#  {'lat': 42.003412,
#   'locationmode': 'USA-states',
#   'lon': -87.697463,
#   'name': 'BOONE',
#   'type': 'scattergeo'},
#  {'lat': 41.749339,
#   'locationmode': 'USA-states',
#   'lon': -87.669366,
#   'name': 'JOPLIN',
#   'type': 'scattergeo'},
#  {'lat': 41.754365,
#   'locationmode': 'USA-states',
#   'lon': -87.557142,
#   'name': 'BRADWELL',
#   'type': 'scattergeo'},
#  {'lat': 41.753457,
#   'locationmode': 'USA-states',
#   'lon': -87.708731,
#   'name': 'HAMPTON',
#   'type': 'scattergeo'},
#  {'lat': 41.686659999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.63363199999999,
#   'name': 'HALEY',
#   'type': 'scattergeo'},
#  {'lat': 41.930966,
#   'locationmode': 'USA-states',
#   'lon': -87.696294,
#   'name': 'BRENTANO',
#   'type': 'scattergeo'},
#  {'lat': 41.949114,
#   'locationmode': 'USA-states',
#   'lon': -87.79866899999999,
#   'name': 'BRIDGE',
#   'type': 'scattergeo'},
#  {'lat': 41.699726,
#   'locationmode': 'USA-states',
#   'lon': -87.562084,
#   'name': 'BRIGHT',
#   'type': 'scattergeo'},
#  {'lat': 41.882996999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.670682,
#   'name': 'BROWN W',
#   'type': 'scattergeo'},
#  {'lat': 41.77162,
#   'locationmode': 'USA-states',
#   'lon': -87.621746,
#   'name': 'BROWNELL',
#   'type': 'scattergeo'},
#  {'lat': 41.760847,
#   'locationmode': 'USA-states',
#   'lon': -87.576075,
#   'name': 'BOUCHET',
#   'type': 'scattergeo'},
#  {'lat': 41.975753999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.696556,
#   'name': 'BUDLONG',
#   'type': 'scattergeo'},
#  {'lat': 41.917598,
#   'locationmode': 'USA-states',
#   'lon': -87.7827,
#   'name': 'BURBANK',
#   'type': 'scattergeo'},
#  {'lat': 41.79676,
#   'locationmode': 'USA-states',
#   'lon': -87.616141,
#   'name': 'BURKE',
#   'type': 'scattergeo'},
#  {'lat': 41.937937,
#   'locationmode': 'USA-states',
#   'lon': -87.669853,
#   'name': 'BURLEY',
#   'type': 'scattergeo'},
#  {'lat': 41.714402,
#   'locationmode': 'USA-states',
#   'lon': -87.567131,
#   'name': 'BURNHAM',
#   'type': 'scattergeo'},
#  {'lat': 41.84545,
#   'locationmode': 'USA-states',
#   'lon': -87.714927,
#   'name': 'CASTELLANOS',
#   'type': 'scattergeo'},
#  {'lat': 41.728481,
#   'locationmode': 'USA-states',
#   'lon': -87.607435,
#   'name': 'BURNSIDE',
#   'type': 'scattergeo'},
#  {'lat': 41.912358000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.668661,
#   'name': 'BURR',
#   'type': 'scattergeo'},
#  {'lat': 41.828868,
#   'locationmode': 'USA-states',
#   'lon': -87.69245699999999,
#   'name': 'BURROUGHS',
#   'type': 'scattergeo'},
#  {'lat': 41.897663,
#   'locationmode': 'USA-states',
#   'lon': -87.765606,
#   'name': 'BRUNSON',
#   'type': 'scattergeo'},
#  {'lat': 41.795031,
#   'locationmode': 'USA-states',
#   'lon': -87.79154399999999,
#   'name': 'BYRNE',
#   'type': 'scattergeo'},
#  {'lat': 41.739226,
#   'locationmode': 'USA-states',
#   'lon': -87.580729,
#   'name': 'CALDWELL',
#   'type': 'scattergeo'},
#  {'lat': 41.843697999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.71731899999999,
#   'name': 'LITTLE VILLAGE',
#   'type': 'scattergeo'},
#  {'lat': 41.903791999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.717927,
#   'name': 'CAMERON',
#   'type': 'scattergeo'},
#  {'lat': 41.948007000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.829296,
#   'name': 'CANTY',
#   'type': 'scattergeo'},
#  {'lat': 41.783367999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.590795,
#   'name': 'CARNEGIE',
#   'type': 'scattergeo'},
#  {'lat': 41.742517,
#   'locationmode': 'USA-states',
#   'lon': -87.696012,
#   'name': 'CARROLL',
#   'type': 'scattergeo'},
#  {'lat': 41.793271999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.6878,
#   'name': 'CARSON',
#   'type': 'scattergeo'},
#  {'lat': 41.789828,
#   'locationmode': 'USA-states',
#   'lon': -87.62245300000001,
#   'name': 'CARTER',
#   'type': 'scattergeo'},
#  {'lat': 41.653702,
#   'locationmode': 'USA-states',
#   'lon': -87.59951600000001,
#   'name': 'CARVER G',
#   'type': 'scattergeo'},
#  {'lat': 41.657405,
#   'locationmode': 'USA-states',
#   'lon': -87.606474,
#   'name': 'ALDRIDGE',
#   'type': 'scattergeo'},
#  {'lat': 41.687346999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.703215,
#   'name': 'CASSELL',
#   'type': 'scattergeo'},
#  {'lat': 41.95281,
#   'locationmode': 'USA-states',
#   'lon': -87.65098,
#   'name': 'GREELEY',
#   'type': 'scattergeo'},
#  {'lat': 41.866434999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.695259,
#   'name': 'CHALMERS',
#   'type': 'scattergeo'},
#  {'lat': 41.975894,
#   'locationmode': 'USA-states',
#   'lon': -87.68326400000001,
#   'name': 'CHAPPELL',
#   'type': 'scattergeo'},
#  {'lat': 41.917993,
#   'locationmode': 'USA-states',
#   'lon': -87.694562,
#   'name': 'CHASE',
#   'type': 'scattergeo'},
#  {'lat': 41.896713,
#   'locationmode': 'USA-states',
#   'lon': -87.688937,
#   'name': 'CHOPIN',
#   'type': 'scattergeo'},
#  {'lat': 41.801659,
#   'locationmode': 'USA-states',
#   'lon': -87.68560699999999,
#   'name': 'CHRISTOPHER',
#   'type': 'scattergeo'},
#  {'lat': 41.654558,
#   'locationmode': 'USA-states',
#   'lon': -87.544614,
#   'name': 'CLAY',
#   'type': 'scattergeo'},
#  {'lat': 41.952042,
#   'locationmode': 'USA-states',
#   'lon': -87.70644300000001,
#   'name': 'CLEVELAND',
#   'type': 'scattergeo'},
#  {'lat': 41.992540999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.69836,
#   'name': 'CLINTON',
#   'type': 'scattergeo'},
#  {'lat': 41.693026,
#   'locationmode': 'USA-states',
#   'lon': -87.680897,
#   'name': 'CLISSOLD',
#   'type': 'scattergeo'},
#  {'lat': 41.741413,
#   'locationmode': 'USA-states',
#   'lon': -87.56597,
#   'name': 'COLES',
#   'type': 'scattergeo'},
#  {'lat': 41.899566,
#   'locationmode': 'USA-states',
#   'lon': -87.681938,
#   'name': 'COLUMBUS',
#   'type': 'scattergeo'},
#  {'lat': 41.745237,
#   'locationmode': 'USA-states',
#   'lon': -87.659775,
#   'name': 'COOK',
#   'type': 'scattergeo'},
#  {'lat': 42.017088,
#   'locationmode': 'USA-states',
#   'lon': -87.677763,
#   'name': 'JORDAN',
#   'type': 'scattergeo'},
#  {'lat': 41.955553,
#   'locationmode': 'USA-states',
#   'lon': -87.68376500000001,
#   'name': 'COONLEY',
#   'type': 'scattergeo'},
#  {'lat': 41.856031,
#   'locationmode': 'USA-states',
#   'lon': -87.667227,
#   'name': 'COOPER',
#   'type': 'scattergeo'},
#  {'lat': 41.784681,
#   'locationmode': 'USA-states',
#   'lon': -87.657169,
#   'name': 'LANGFORD',
#   'type': 'scattergeo'},
#  {'lat': 41.845602,
#   'locationmode': 'USA-states',
#   'lon': -87.731193,
#   'name': 'CORKERY',
#   'type': 'scattergeo'},
#  {'lat': 41.688190999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.685677,
#   'name': 'VICK',
#   'type': 'scattergeo'},
#  {'lat': 41.856029,
#   'locationmode': 'USA-states',
#   'lon': -87.65798000000001,
#   'name': 'PEREZ',
#   'type': 'scattergeo'},
#  {'lat': 41.852663,
#   'locationmode': 'USA-states',
#   'lon': -87.71247,
#   'name': 'CROWN',
#   'type': 'scattergeo'},
#  {'lat': 41.973715000000006,
#   'locationmode': 'USA-states',
#   'lon': -87.841041,
#   'name': 'DIRKSEN',
#   'type': 'scattergeo'},
#  {'lat': 41.923322999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.70541300000001,
#   'name': 'DARWIN',
#   'type': 'scattergeo'},
#  {'lat': 41.821852,
#   'locationmode': 'USA-states',
#   'lon': -87.700202,
#   'name': 'DAVIS N',
#   'type': 'scattergeo'},
#  {'lat': 41.745078,
#   'locationmode': 'USA-states',
#   'lon': -87.717353,
#   'name': 'DAWES',
#   'type': 'scattergeo'},
#  {'lat': 42.009289,
#   'locationmode': 'USA-states',
#   'lon': -87.704619,
#   'name': 'DECATUR',
#   'type': 'scattergeo'},
#  {'lat': 41.76249,
#   'locationmode': 'USA-states',
#   'lon': -87.623345,
#   'name': 'DENEEN',
#   'type': 'scattergeo'},
#  {'lat': 41.942552,
#   'locationmode': 'USA-states',
#   'lon': -87.813132,
#   'name': 'DEVER',
#   'type': 'scattergeo'},
#  {'lat': 41.795646000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.642652,
#   'name': 'DEWEY',
#   'type': 'scattergeo'},
#  {'lat': 41.743669,
#   'locationmode': 'USA-states',
#   'lon': -87.60997900000001,
#   'name': 'DIXON',
#   'type': 'scattergeo'},
#  {'lat': 41.889184,
#   'locationmode': 'USA-states',
#   'lon': -87.70379399999999,
#   'name': 'DODGE',
#   'type': 'scattergeo'},
#  {'lat': 41.831121,
#   'locationmode': 'USA-states',
#   'lon': -87.612275,
#   'name': 'DOOLITTLE',
#   'type': 'scattergeo'},
#  {'lat': 41.780954,
#   'locationmode': 'USA-states',
#   'lon': -87.787604,
#   'name': 'DORE',
#   'type': 'scattergeo'},
#  {'lat': 41.844043,
#   'locationmode': 'USA-states',
#   'lon': -87.628553,
#   'name': 'DRAKE',
#   'type': 'scattergeo'},
#  {'lat': 41.725609000000006,
#   'locationmode': 'USA-states',
#   'lon': -87.63016400000001,
#   'name': 'TURNER-DREW',
#   'type': 'scattergeo'},
#  {'lat': 41.915914,
#   'locationmode': 'USA-states',
#   'lon': -87.674495,
#   'name': 'DRUMMOND',
#   'type': 'scattergeo'},
#  {'lat': 41.781225,
#   'locationmode': 'USA-states',
#   'lon': -87.675547,
#   'name': 'EARLE',
#   'type': 'scattergeo'},
#  {'lat': 41.77442,
#   'locationmode': 'USA-states',
#   'lon': -87.707953,
#   'name': 'EBERHART',
#   'type': 'scattergeo'},
#  {'lat': 42.004408000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.81116999999999,
#   'name': 'EBINGER',
#   'type': 'scattergeo'},
#  {'lat': 41.685418,
#   'locationmode': 'USA-states',
#   'lon': -87.62165300000001,
#   'name': 'CURTIS',
#   'type': 'scattergeo'},
#  {'lat': 41.999437,
#   'locationmode': 'USA-states',
#   'lon': -87.76184,
#   'name': 'EDGEBROOK',
#   'type': 'scattergeo'},
#  {'lat': 41.669444,
#   'locationmode': 'USA-states',
#   'lon': -87.63430600000001,
#   'name': 'METCALFE',
#   'type': 'scattergeo'},
#  {'lat': 41.805541999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.72585600000001,
#   'name': 'EDWARDS',
#   'type': 'scattergeo'},
#  {'lat': 41.885529999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.766589,
#   'name': 'ELLINGTON',
#   'type': 'scattergeo'},
#  {'lat': 41.875744,
#   'locationmode': 'USA-states',
#   'lon': -87.715804,
#   'name': 'ERICSON',
#   'type': 'scattergeo'},
#  {'lat': 41.68942,
#   'locationmode': 'USA-states',
#   'lon': -87.669159,
#   'name': 'ESMOND',
#   'type': 'scattergeo'},
#  {'lat': 41.831555,
#   'locationmode': 'USA-states',
#   'lon': -87.68131,
#   'name': 'EVERETT',
#   'type': 'scattergeo'},
#  {'lat': 41.935784999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.74933100000001,
#   'name': 'FALCONER',
#   'type': 'scattergeo'},
#  {'lat': 41.97979,
#   'locationmode': 'USA-states',
#   'lon': -87.766072,
#   'name': 'FARNSWORTH',
#   'type': 'scattergeo'},
#  {'lat': 41.711184,
#   'locationmode': 'USA-states',
#   'lon': -87.640414,
#   'name': 'FERNWOOD',
#   'type': 'scattergeo'},
#  {'lat': 42.009664,
#   'locationmode': 'USA-states',
#   'lon': -87.669985,
#   'name': 'FIELD',
#   'type': 'scattergeo'},
#  {'lat': 41.785183,
#   'locationmode': 'USA-states',
#   'lon': -87.608633,
#   'name': 'FISKE',
#   'type': 'scattergeo'},
#  {'lat': 41.850771,
#   'locationmode': 'USA-states',
#   'lon': -87.705112,
#   'name': 'KANOON',
#   'type': 'scattergeo'},
#  {'lat': 41.847947,
#   'locationmode': 'USA-states',
#   'lon': -87.69600600000001,
#   'name': 'TELPOCHCALLI',
#   'type': 'scattergeo'},
#  {'lat': 41.92015,
#   'locationmode': 'USA-states',
#   'lon': -87.756843,
#   'name': 'BELMONT-CRAGIN',
#   'type': 'scattergeo'},
#  {'lat': 41.729673,
#   'locationmode': 'USA-states',
#   'lon': -87.65548100000001,
#   'name': 'FORT DEARBORN',
#   'type': 'scattergeo'},
#  {'lat': 41.870168,
#   'locationmode': 'USA-states',
#   'lon': -87.702163,
#   'name': 'KELLMAN',
#   'type': 'scattergeo'},
#  {'lat': 41.9066,
#   'locationmode': 'USA-states',
#   'lon': -87.635513,
#   'name': 'FRANKLIN',
#   'type': 'scattergeo'},
#  {'lat': 41.738425,
#   'locationmode': 'USA-states',
#   'lon': -87.668099,
#   'name': 'FOSTER PARK',
#   'type': 'scattergeo'},
#  {'lat': 41.818003000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.611784,
#   'name': 'FULLER',
#   'type': 'scattergeo'},
#  {'lat': 41.797579999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.668436,
#   'name': 'FULTON',
#   'type': 'scattergeo'},
#  {'lat': 41.917617,
#   'locationmode': 'USA-states',
#   'lon': -87.716892,
#   'name': 'FUNSTON',
#   'type': 'scattergeo'},
#  {'lat': 42.021091,
#   'locationmode': 'USA-states',
#   'lon': -87.671939,
#   'name': 'GALE',
#   'type': 'scattergeo'},
#  {'lat': 41.706801,
#   'locationmode': 'USA-states',
#   'lon': -87.535175,
#   'name': 'GALLISTEL',
#   'type': 'scattergeo'},
#  {'lat': 41.976352,
#   'locationmode': 'USA-states',
#   'lon': -87.796235,
#   'name': 'GARVY',
#   'type': 'scattergeo'},
#  {'lat': 41.837065,
#   'locationmode': 'USA-states',
#   'lon': -87.71869699999999,
#   'name': 'GARY',
#   'type': 'scattergeo'},
#  {'lat': 41.725332,
#   'locationmode': 'USA-states',
#   'lon': -87.623719,
#   'name': 'GILLESPIE',
#   'type': 'scattergeo'},
#  {'lat': 41.760614000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.675966,
#   'name': 'RANDOLPH',
#   'type': 'scattergeo'},
#  {'lat': 41.922831,
#   'locationmode': 'USA-states',
#   'lon': -87.6929,
#   'name': 'GOETHE',
#   'type': 'scattergeo'},
#  {'lat': 41.670618,
#   'locationmode': 'USA-states',
#   'lon': -87.622546,
#   'name': 'OWENS',
#   'type': 'scattergeo'},
#  {'lat': 41.662481,
#   'locationmode': 'USA-states',
#   'lon': -87.55330699999999,
#   'name': 'GRISSOM',
#   'type': 'scattergeo'},
#  {'lat': 41.975817,
#   'locationmode': 'USA-states',
#   'lon': -87.657912,
#   'name': 'GOUDY',
#   'type': 'scattergeo'},
#  {'lat': 41.813303999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.643344,
#   'name': 'GRAHAM ES',
#   'type': 'scattergeo'},
#  {'lat': 41.948764000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.757116,
#   'name': 'GRAY',
#   'type': 'scattergeo'},
#  {'lat': 41.838791,
#   'locationmode': 'USA-states',
#   'lon': -87.71719,
#   'name': 'ORTIZ DE DOMINGUEZ',
#   'type': 'scattergeo'},
#  {'lat': 41.811173,
#   'locationmode': 'USA-states',
#   'lon': -87.597503,
#   'name': 'ARIEL',
#   'type': 'scattergeo'},
#  {'lat': 41.829669,
#   'locationmode': 'USA-states',
#   'lon': -87.671492,
#   'name': 'GREENE',
#   'type': 'scattergeo'},
#  {'lat': 41.870742,
#   'locationmode': 'USA-states',
#   'lon': -87.718666,
#   'name': 'GREGORY',
#   'type': 'scattergeo'},
#  {'lat': 41.73892,
#   'locationmode': 'USA-states',
#   'lon': -87.645025,
#   'name': 'GRESHAM',
#   'type': 'scattergeo'},
#  {'lat': 41.775464,
#   'locationmode': 'USA-states',
#   'lon': -87.758803,
#   'name': 'GRIMES',
#   'type': 'scattergeo'},
#  {'lat': 41.813007,
#   'locationmode': 'USA-states',
#   'lon': -87.699364,
#   'name': 'GUNSAULUS',
#   'type': 'scattergeo'},
#  {'lat': 41.849958,
#   'locationmode': 'USA-states',
#   'lon': -87.633806,
#   'name': 'HAINES',
#   'type': 'scattergeo'},
#  {'lat': 41.780192,
#   'locationmode': 'USA-states',
#   'lon': -87.776579,
#   'name': 'HALE',
#   'type': 'scattergeo'},
#  {'lat': 41.743753000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.551862,
#   'name': 'NINOS HEROES',
#   'type': 'scattergeo'},
#  {'lat': 41.94522,
#   'locationmode': 'USA-states',
#   'lon': -87.670865,
#   'name': 'HAMILTON',
#   'type': 'scattergeo'},
#  {'lat': 41.807241999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.661175,
#   'name': 'HAMLINE',
#   'type': 'scattergeo'},
#  {'lat': 41.852719,
#   'locationmode': 'USA-states',
#   'lon': -87.69624300000001,
#   'name': 'HAMMOND',
#   'type': 'scattergeo'},
#  {'lat': 41.849215,
#   'locationmode': 'USA-states',
#   'lon': -87.685668,
#   'name': 'FINKL',
#   'type': 'scattergeo'},
#  {'lat': 41.914815999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.72393100000001,
#   'name': 'MCAULIFFE',
#   'type': 'scattergeo'},
#  {'lat': 41.793447,
#   'locationmode': 'USA-states',
#   'lon': -87.586855,
#   'name': 'HARTE',
#   'type': 'scattergeo'},
#  {'lat': 41.757341,
#   'locationmode': 'USA-states',
#   'lon': -87.632737,
#   'name': 'HARVARD',
#   'type': 'scattergeo'},
#  {'lat': 41.964029,
#   'locationmode': 'USA-states',
#   'lon': -87.723128,
#   'name': 'HAUGAN',
#   'type': 'scattergeo'},
#  {'lat': 41.841394,
#   'locationmode': 'USA-states',
#   'lon': -87.734313,
#   'name': 'ZAPATA',
#   'type': 'scattergeo'},
#  {'lat': 41.942275,
#   'locationmode': 'USA-states',
#   'lon': -87.657709,
#   'name': 'HAWTHORNE',
#   'type': 'scattergeo'},
#  {'lat': 41.899171,
#   'locationmode': 'USA-states',
#   'lon': -87.755813,
#   'name': 'HAY',
#   'type': 'scattergeo'},
#  {'lat': 41.994541,
#   'locationmode': 'USA-states',
#   'lon': -87.668504,
#   'name': 'HAYT',
#   'type': 'scattergeo'},
#  {'lat': 41.773365999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.594392,
#   'name': 'WOODLAWN',
#   'type': 'scattergeo'},
#  {'lat': 41.707558,
#   'locationmode': 'USA-states',
#   'lon': -87.60466,
#   'name': 'SMITH',
#   'type': 'scattergeo'},
#  {'lat': 41.839595,
#   'locationmode': 'USA-states',
#   'lon': -87.640341,
#   'name': 'HEALY',
#   'type': 'scattergeo'},
#  {'lat': 41.808175,
#   'locationmode': 'USA-states',
#   'lon': -87.745726,
#   'name': 'HEARST',
#   'type': 'scattergeo'},
#  {'lat': 41.807112,
#   'locationmode': 'USA-states',
#   'lon': -87.673327,
#   'name': 'HEDGES',
#   'type': 'scattergeo'},
#  {'lat': 41.878665000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.735802,
#   'name': 'HEFFERAN',
#   'type': 'scattergeo'},
#  {'lat': 41.790591,
#   'locationmode': 'USA-states',
#   'lon': -87.671887,
#   'name': 'HENDERSON',
#   'type': 'scattergeo'},
#  {'lat': 41.815788,
#   'locationmode': 'USA-states',
#   'lon': -87.633664,
#   'name': 'HENDRICKS',
#   'type': 'scattergeo'},
#  {'lat': 41.958989,
#   'locationmode': 'USA-states',
#   'lon': -87.715632,
#   'name': 'HENRY',
#   'type': 'scattergeo'},
#  {'lat': 41.866875,
#   'locationmode': 'USA-states',
#   'lon': -87.628615,
#   'name': 'SOUTH LOOP',
#   'type': 'scattergeo'},
#  {'lat': 41.862080999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.718994,
#   'name': 'HERZL',
#   'type': 'scattergeo'},
#  {'lat': 41.80977,
#   'locationmode': 'USA-states',
#   'lon': -87.67218199999999,
#   'name': 'LARA',
#   'type': 'scattergeo'},
#  {'lat': 41.970335,
#   'locationmode': 'USA-states',
#   'lon': -87.710362,
#   'name': 'HIBBARD',
#   'type': 'scattergeo'},
#  {'lat': 41.983672,
#   'locationmode': 'USA-states',
#   'lon': -87.779123,
#   'name': 'HITCH',
#   'type': 'scattergeo'},
#  {'lat': 41.838027000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.65379200000001,
#   'name': 'HOLDEN',
#   'type': 'scattergeo'},
#  {'lat': 41.793788,
#   'locationmode': 'USA-states',
#   'lon': -87.649795,
#   'name': 'HOLMES',
#   'type': 'scattergeo'},
#  {'lat': 41.893612,
#   'locationmode': 'USA-states',
#   'lon': -87.759398,
#   'name': 'HOWE',
#   'type': 'scattergeo'},
#  {'lat': 41.733338,
#   'locationmode': 'USA-states',
#   'lon': -87.568228,
#   'name': 'HOYNE',
#   'type': 'scattergeo'},
#  {'lat': 41.742452,
#   'locationmode': 'USA-states',
#   'lon': -87.653633,
#   'name': 'CUFFE',
#   'type': 'scattergeo'},
#  {'lat': 41.700334999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.611244,
#   'name': 'CULLEN',
#   'type': 'scattergeo'},
#  {'lat': 41.860518,
#   'locationmode': 'USA-states',
#   'lon': -87.73177700000001,
#   'name': 'HUGHES C',
#   'type': 'scattergeo'},
#  {'lat': 41.766785,
#   'locationmode': 'USA-states',
#   'lon': -87.719541,
#   'name': 'HURLEY',
#   'type': 'scattergeo'},
#  {'lat': 41.871255,
#   'locationmode': 'USA-states',
#   'lon': -87.653366,
#   'name': 'GALILEO',
#   'type': 'scattergeo'},
#  {'lat': 41.939246999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.67581,
#   'name': 'JAHN',
#   'type': 'scattergeo'},
#  {'lat': 41.984640999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.700529,
# ...
#  {'lat': 41.798465,
#   'locationmode': 'USA-states',
#   'lon': -87.625692,
#   'name': 'BEASLEY',
#   'type': 'scattergeo'},
#  {'lat': 41.943056,
#   'locationmode': 'USA-states',
#   'lon': -87.778187,
#   'name': 'CHICAGO ACADEMY ES',
#   'type': 'scattergeo'},
#  {'lat': 41.794048,
#   'locationmode': 'USA-states',
#   'lon': -87.69026099999999,
#   'name': 'TALMAN',
#   'type': 'scattergeo'},
#  {'lat': 41.901416999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.63363199999999,
#   'name': 'SALAZAR',
#   'type': 'scattergeo'},
#  {'lat': 41.88295,
#   'locationmode': 'USA-states',
#   'lon': -87.699187,
#   'name': 'CATHER',
#   'type': 'scattergeo'},
#  {'lat': 41.879870000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.68031500000001,
#   'name': 'DETT',
#   'type': 'scattergeo'},
#  {'lat': 41.858883,
#   'locationmode': 'USA-states',
#   'lon': -87.715744,
#   'name': 'DVORAK',
#   'type': 'scattergeo'},
#  {'lat': 41.817349,
#   'locationmode': 'USA-states',
#   'lon': -87.599067,
#   'name': 'ROBINSON',
#   'type': 'scattergeo'},
#  {'lat': 41.889178,
#   'locationmode': 'USA-states',
#   'lon': -87.705108,
#   'name': 'MORTON',
#   'type': 'scattergeo'},
#  {'lat': 41.7799,
#   'locationmode': 'USA-states',
#   'lon': -87.617214,
#   'name': 'DULLES',
#   'type': 'scattergeo'},
#  {'lat': 41.740184,
#   'locationmode': 'USA-states',
#   'lon': -87.601174,
#   'name': 'ASHE',
#   'type': 'scattergeo'},
#  {'lat': 41.970949,
#   'locationmode': 'USA-states',
#   'lon': -87.654758,
#   'name': 'MCCUTCHEON',
#   'type': 'scattergeo'},
#  {'lat': 41.873815,
#   'locationmode': 'USA-states',
#   'lon': -87.702241,
#   'name': 'JENSEN',
#   'type': 'scattergeo'},
#  {'lat': 41.861836,
#   'locationmode': 'USA-states',
#   'lon': -87.70313900000001,
#   'name': 'JOHNSON',
#   'type': 'scattergeo'},
#  {'lat': 41.814358,
#   'locationmode': 'USA-states',
#   'lon': -87.616618,
#   'name': 'MOLLISON',
#   'type': 'scattergeo'},
#  {'lat': 41.760673,
#   'locationmode': 'USA-states',
#   'lon': -87.606791,
#   'name': 'TANNER',
#   'type': 'scattergeo'},
#  {'lat': 41.760332,
#   'locationmode': 'USA-states',
#   'lon': -87.556789,
#   'name': 'POWELL',
#   'type': 'scattergeo'},
#  {'lat': 41.897819,
#   'locationmode': 'USA-states',
#   'lon': -87.74673100000001,
#   'name': 'MCNAIR',
#   'type': 'scattergeo'},
#  {'lat': 42.007703,
#   'locationmode': 'USA-states',
#   'lon': -87.673168,
#   'name': 'NEW FIELD',
#   'type': 'scattergeo'},
#  {'lat': 41.742351,
#   'locationmode': 'USA-states',
#   'lon': -87.70961,
#   'name': 'ASHBURN',
#   'type': 'scattergeo'},
#  {'lat': 41.772727,
#   'locationmode': 'USA-states',
#   'lon': -87.637277,
#   'name': 'MAYS',
#   'type': 'scattergeo'},
#  {'lat': 41.775304999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.728884,
#   'name': 'LEE',
#   'type': 'scattergeo'},
#  {'lat': 41.878799,
#   'locationmode': 'USA-states',
#   'lon': -87.724661,
#   'name': 'MELODY',
#   'type': 'scattergeo'},
#  {'lat': 41.681031,
#   'locationmode': 'USA-states',
#   'lon': -87.64699399999999,
#   'name': 'HIGGINS',
#   'type': 'scattergeo'},
#  {'lat': 41.747186,
#   'locationmode': 'USA-states',
#   'lon': -87.62804,
#   'name': 'LENART',
#   'type': 'scattergeo'},
#  {'lat': 41.765335,
#   'locationmode': 'USA-states',
#   'lon': -87.641335,
#   'name': 'KING ES',
#   'type': 'scattergeo'},
#  {'lat': 41.748868,
#   'locationmode': 'USA-states',
#   'lon': -87.634751,
#   'name': 'WESTCOTT',
#   'type': 'scattergeo'},
#  {'lat': 41.879118,
#   'locationmode': 'USA-states',
#   'lon': -87.68696,
#   'name': 'PHOENIX MILITARY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.873587,
#   'locationmode': 'USA-states',
#   'lon': -87.749276,
#   'name': 'LELAND',
#   'type': 'scattergeo'},
#  {'lat': 41.883568,
#   'locationmode': 'USA-states',
#   'lon': -87.669477,
#   'name': 'RUDOLPH',
#   'type': 'scattergeo'},
#  {'lat': 41.733132,
#   'locationmode': 'USA-states',
#   'lon': -87.589589,
#   'name': 'MCDOWELL',
#   'type': 'scattergeo'},
#  {'lat': 41.905294,
#   'locationmode': 'USA-states',
#   'lon': -87.68575600000001,
#   'name': 'DE DIEGO',
#   'type': 'scattergeo'},
#  {'lat': 41.672309000000006,
#   'locationmode': 'USA-states',
#   'lon': -87.650539,
#   'name': 'WHITE',
#   'type': 'scattergeo'},
#  {'lat': 41.726107,
#   'locationmode': 'USA-states',
#   'lon': -87.58218199999999,
#   'name': 'EARHART',
#   'type': 'scattergeo'},
#  {'lat': 41.8239,
#   'locationmode': 'USA-states',
#   'lon': -87.692077,
#   'name': 'BRIGHTON PARK',
#   'type': 'scattergeo'},
#  {'lat': 41.829356,
#   'locationmode': 'USA-states',
#   'lon': -87.667817,
#   'name': 'EVERGREEN',
#   'type': 'scattergeo'},
#  {'lat': 41.952492,
#   'locationmode': 'USA-states',
#   'lon': -87.719988,
#   'name': 'MARSHALL MIDDLE',
#   'type': 'scattergeo'},
#  {'lat': 41.734627,
#   'locationmode': 'USA-states',
#   'lon': -87.55755,
#   'name': 'BOWEN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.93397,
#   'locationmode': 'USA-states',
#   'lon': -87.70804100000001,
#   'name': 'LOGANDALE',
#   'type': 'scattergeo'},
#  {'lat': 41.857755,
#   'locationmode': 'USA-states',
#   'lon': -87.67520999999999,
#   'name': 'OROZCO',
#   'type': 'scattergeo'},
#  {'lat': 41.88621,
#   'locationmode': 'USA-states',
#   'lon': -87.715423,
#   'name': 'RABY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.758925,
#   'locationmode': 'USA-states',
#   'lon': -87.64921700000001,
#   'name': 'STAGG',
#   'type': 'scattergeo'},
#  {'lat': 41.943054,
#   'locationmode': 'USA-states',
#   'lon': -87.776847,
#   'name': 'CHICAGO ACADEMY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.906816,
#   'locationmode': 'USA-states',
#   'lon': -87.68305,
#   'name': 'SABIN',
#   'type': 'scattergeo'},
#  {'lat': 41.814499,
#   'locationmode': 'USA-states',
#   'lon': -87.608419,
#   'name': 'WOODSON',
#   'type': 'scattergeo'},
#  {'lat': 41.777511,
#   'locationmode': 'USA-states',
#   'lon': -87.681061,
#   'name': 'CLAREMONT',
#   'type': 'scattergeo'},
#  {'lat': 41.729692,
#   'locationmode': 'USA-states',
#   'lon': -87.576643,
#   'name': 'BLACK',
#   'type': 'scattergeo'},
#  {'lat': 41.738844,
#   'locationmode': 'USA-states',
#   'lon': -87.729955,
#   'name': 'DURKIN PARK',
#   'type': 'scattergeo'},
#  {'lat': 41.824377,
#   'locationmode': 'USA-states',
#   'lon': -87.71165400000001,
#   'name': 'CALMECA',
#   'type': 'scattergeo'},
#  {'lat': 41.961721000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.707151,
#   'name': 'NORTH RIVER',
#   'type': 'scattergeo'},
#  {'lat': 41.962308,
#   'locationmode': 'USA-states',
#   'lon': -87.663853,
#   'name': 'COURTENAY',
#   'type': 'scattergeo'},
#  {'lat': 41.847762,
#   'locationmode': 'USA-states',
#   'lon': -87.69894599999999,
#   'name': 'SPRY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.715665,
#   'locationmode': 'USA-states',
#   'lon': -87.63930500000001,
#   'name': 'EVERS',
#   'type': 'scattergeo'},
#  {'lat': 41.956815999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.64608299999999,
#   'name': 'DISNEY',
#   'type': 'scattergeo'},
#  {'lat': 41.653733,
#   'locationmode': 'USA-states',
#   'lon': -87.61431999999999,
#   'name': 'DUBOIS',
#   'type': 'scattergeo'},
#  {'lat': 41.716193,
#   'locationmode': 'USA-states',
#   'lon': -87.648044,
#   'name': 'WACKER',
#   'type': 'scattergeo'},
#  {'lat': 41.877978999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.76629799999999,
#   'name': 'DEPRIEST',
#   'type': 'scattergeo'},
#  {'lat': 41.705342,
#   'locationmode': 'USA-states',
#   'lon': -87.629869,
#   'name': 'HUGHES L',
#   'type': 'scattergeo'},
#  {'lat': 41.734125,
#   'locationmode': 'USA-states',
#   'lon': -87.64676700000001,
#   'name': 'JACKSON M',
#   'type': 'scattergeo'},
#  {'lat': 41.806118,
#   'locationmode': 'USA-states',
#   'lon': -87.62503000000001,
#   'name': 'WILLIAMS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.805203999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.625004,
#   'name': 'BRONZEVILLE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.833507,
#   'locationmode': 'USA-states',
#   'lon': -87.735299,
#   'name': 'SOCIAL JUSTICE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.836169,
#   'locationmode': 'USA-states',
#   'lon': -87.73527800000001,
#   'name': 'INFINITY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.835282,
#   'locationmode': 'USA-states',
#   'lon': -87.735283,
#   'name': 'MULTICULTURAL HS',
#   'type': 'scattergeo'},
#  {'lat': 41.803515000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.667378,
#   'name': 'PEACE AND EDUCATION HS',
#   'type': 'scattergeo'},
#  {'lat': 41.894449,
#   'locationmode': 'USA-states',
#   'lon': -87.726166,
#   'name': 'ORR HS',
#   'type': 'scattergeo'},
#  {'lat': 41.989021,
#   'locationmode': 'USA-states',
#   'lon': -87.665789,
#   'name': 'RICKOVER MILITARY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.782041,
#   'locationmode': 'USA-states',
#   'lon': -87.671662,
#   'name': 'LINDBLOM HS',
#   'type': 'scattergeo'},
#  {'lat': 41.834396999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.735292,
#   'name': 'WORLD LANGUAGE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.965546999999994,
#   'locationmode': 'USA-states',
#   'lon': -87.652473,
#   'name': 'UPLIFT HS',
#   'type': 'scattergeo'},
#  {'lat': 41.764407,
#   'locationmode': 'USA-states',
#   'lon': -87.706445,
#   'name': 'TARKINGTON',
#   'type': 'scattergeo'},
#  {'lat': 41.941388,
#   'locationmode': 'USA-states',
#   'lon': -87.690761,
#   'name': 'DEVRY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.883215,
#   'locationmode': 'USA-states',
#   'lon': -87.67763599999999,
#   'name': 'SUDER',
#   'type': 'scattergeo'},
#  {'lat': 41.864149,
#   'locationmode': 'USA-states',
#   'lon': -87.702042,
#   'name': 'COLLINS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.885123,
#   'locationmode': 'USA-states',
#   'lon': -87.761909,
#   'name': 'AUSTIN POLY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.879123,
#   'locationmode': 'USA-states',
#   'lon': -87.688314,
#   'name': 'MARINE MILITARY HS',
#   'type': 'scattergeo'},
#  {'lat': 41.86698,
#   'locationmode': 'USA-states',
#   'lon': -87.727244,
#   'name': 'FRAZIER PROSPECTIVE',
#   'type': 'scattergeo'},
#  {'lat': 41.827775,
#   'locationmode': 'USA-states',
#   'lon': -87.677542,
#   'name': 'THOMAS',
#   'type': 'scattergeo'},
#  {'lat': 41.781484999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.63301899999999,
#   'name': 'TEAM HS',
#   'type': 'scattergeo'},
#  {'lat': 41.828145,
#   'locationmode': 'USA-states',
#   'lon': -87.632757,
#   'name': 'AIR FORCE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.885993,
#   'locationmode': 'USA-states',
#   'lon': -87.761916,
#   'name': 'VOISE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.902914,
#   'locationmode': 'USA-states',
#   'lon': -87.67369599999999,
#   'name': 'LASALLE II',
#   'type': 'scattergeo'},
#  {'lat': 41.771221000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.66653000000001,
#   'name': 'DAVIS M',
#   'type': 'scattergeo'},
#  {'lat': 41.994238,
#   'locationmode': 'USA-states',
#   'lon': -87.813771,
#   'name': 'EDISON PARK',
#   'type': 'scattergeo'},
#  {'lat': 41.935795,
#   'locationmode': 'USA-states',
#   'lon': -87.680562,
#   'name': 'ALCOTT HS',
#   'type': 'scattergeo'},
#  {'lat': 41.893547999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.659405,
#   'name': 'OGDEN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.767755,
#   'locationmode': 'USA-states',
#   'lon': -87.590396,
#   'name': 'SOUTH SHORE',
#   'type': 'scattergeo'},
#  {'lat': 41.793479,
#   'locationmode': 'USA-states',
#   'lon': -87.71137,
#   'name': 'HERNANDEZ',
#   'type': 'scattergeo'},
#  {'lat': 41.921318,
#   'locationmode': 'USA-states',
#   'lon': -87.765781,
#   'name': 'PRIETO',
#   'type': 'scattergeo'},
#  {'lat': 41.905109,
#   'locationmode': 'USA-states',
#   'lon': -87.644841,
#   'name': 'SKINNER NORTH',
#   'type': 'scattergeo'},
#  {'lat': 41.934931,
#   'locationmode': 'USA-states',
#   'lon': -87.770127,
#   'name': 'CAMRAS',
#   'type': 'scattergeo'},
#  {'lat': 41.940026,
#   'locationmode': 'USA-states',
#   'lon': -87.724783,
#   'name': 'LORCA',
#   'type': 'scattergeo'},
#  {'lat': 42.002959000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.705917,
#   'name': 'WEST RIDGE',
#   'type': 'scattergeo'},
#  {'lat': 41.795201,
#   'locationmode': 'USA-states',
#   'lon': -87.71105899999999,
#   'name': 'SOLORIO HS',
#   'type': 'scattergeo'},
#  {'lat': 41.771079,
#   'locationmode': 'USA-states',
#   'lon': -87.73992,
#   'name': 'AZUELA',
#   'type': 'scattergeo'},
#  {'lat': 41.758792,
#   'locationmode': 'USA-states',
#   'lon': -87.576353,
#   'name': 'SOUTH SHORE INTL HS',
#   'type': 'scattergeo'},
#  {'lat': 41.868576000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.664969,
#   'name': 'STEM',
#   'type': 'scattergeo'},
#  {'lat': 41.895678000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.754064,
#   'name': 'BANNER WEST HS',
#   'type': 'scattergeo'},
#  {'lat': 41.735239,
#   'locationmode': 'USA-states',
#   'lon': -87.70406,
#   'name': 'PATHWAYS - ASHBURN HS',
#   'type': 'scattergeo'},
#  {'lat': 41.75375,
#   'locationmode': 'USA-states',
#   'lon': -87.70734499999999,
#   'name': 'GOODE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.806490999999994,
#   'locationmode': 'USA-states',
#   'lon': -87.68978,
#   'name': 'SHIELDS MIDDLE',
#   'type': 'scattergeo'},
#  {'lat': 41.876946999999994,
#   'locationmode': 'USA-states',
#   'lon': -87.683301,
#   'name': 'CRANE MEDICAL HS',
#   'type': 'scattergeo'},
#  {'lat': 41.808413,
#   'locationmode': 'USA-states',
#   'lon': -87.677541,
#   'name': 'BACK OF THE YARDS HS',
#   'type': 'scattergeo'},
#  {'lat': 41.952488,
#   'locationmode': 'USA-states',
#   'lon': -87.72136400000001,
#   'name': 'DISNEY II HS',
#   'type': 'scattergeo'},
#  {'lat': 41.763896,
#   'locationmode': 'USA-states',
#   'lon': -87.649124,
#   'name': 'CAMELOT - EXCEL ENGLEWOOD HS',
#   'type': 'scattergeo'},
#  {'lat': 41.866478,
#   'locationmode': 'USA-states',
#   'lon': -87.706604,
#   'name': 'MAGIC JOHNSON - N LAWNDALE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.695159999999994,
#   'locationmode': 'USA-states',
#   'lon': -87.642697,
#   'name': 'MAGIC JOHNSON - ROSELAND HS',
#   'type': 'scattergeo'},
#  {'lat': 41.939433,
#   'locationmode': 'USA-states',
#   'lon': -87.705206,
#   'name': 'PATHWAYS - AVONDALE HS',
#   'type': 'scattergeo'},
#  {'lat': 42.017171000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.806682,
#   'name': 'OMBUDSMAN - NORTHWEST HS',
#   'type': 'scattergeo'},
#  {'lat': 41.783027000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.683635,
#   'name': 'OMBUDSMAN - SOUTH HS',
#   'type': 'scattergeo'},
#  {'lat': 41.874673,
#   'locationmode': 'USA-states',
#   'lon': -87.687842,
#   'name': 'OMBUDSMAN - WEST HS',
#   'type': 'scattergeo'},
#  {'lat': 41.752016,
#   'locationmode': 'USA-states',
#   'lon': -87.57588299999999,
#   'name': 'PROLOGUE - WINNIE MANDELA HS',
#   'type': 'scattergeo'},
#  {'lat': 41.768729,
#   'locationmode': 'USA-states',
#   'lon': -87.646284,
#   'name': 'MAGIC JOHNSON - ENGLEWOOD HS',
#   'type': 'scattergeo'},
#  {'lat': 41.902925,
#   'locationmode': 'USA-states',
#   'lon': -87.687889,
#   'name': 'MAGIC JOHNSON - HUMBOLDT PK HS',
#   'type': 'scattergeo'},
#  {'lat': 41.742671,
#   'locationmode': 'USA-states',
#   'lon': -87.559907,
#   'name': 'GREAT LAKES',
#   'type': 'scattergeo'},
#  {'lat': 41.753116999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.550513,
#   'name': 'CAMELOT SAFE ES',
#   'type': 'scattergeo'},
#  {'lat': 41.92985,
#   'locationmode': 'USA-states',
#   'lon': -87.646413,
#   'name': 'ALCOTT ES',
#   'type': 'scattergeo'},
#  {'lat': 41.847747,
#   'locationmode': 'USA-states',
#   'lon': -87.700184,
#   'name': 'SPRY ES',
#   'type': 'scattergeo'},
#  {'lat': 41.899976,
#   'locationmode': 'USA-states',
#   'lon': -87.629297,
#   'name': 'OGDEN ES',
#   'type': 'scattergeo'},
#  {'lat': 41.950461,
#   'locationmode': 'USA-states',
#   'lon': -87.730678,
#   'name': 'DISNEY II ES',
#   'type': 'scattergeo'},
#  {'lat': 41.753115,
#   'locationmode': 'USA-states',
#   'lon': -87.551804,
#   'name': 'CAMELOT SAFE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.884503,
#   'locationmode': 'USA-states',
#   'lon': -87.739485,
#   'name': 'CAMELOT SAFE - GARFIELD HS',
#   'type': 'scattergeo'},
#  {'lat': 41.731491999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.66314,
#   'name': 'MAGIC JOHNSON - BRAINERD HS',
#   'type': 'scattergeo'},
#  {'lat': 41.883606,
#   'locationmode': 'USA-states',
#   'lon': -87.73948399999999,
#   'name': 'CAMELOT SAFE - GARFIELD ES',
#   'type': 'scattergeo'},
#  {'lat': 41.935726,
#   'locationmode': 'USA-states',
#   'lon': -87.718204,
#   'name': 'ASPIRA - BUSINESS & FINANCE HS',
#   'type': 'scattergeo'},
#  {'lat': 41.888259000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.75528100000001,
#   'name': 'MOVING EVEREST',
#   'type': 'scattergeo'}]

# %%
for i, v in enumerate(data):
    data[i]['marker'] = dict(
            size = 5,
            color = 'red',
            line = dict(width=0.5, color='rgb(40,40,40)'),
            sizemode = 'area'
        )
    data[i]['lat'] = pd.Series(data[i]['lat'])
    data[i]['lon'] = pd.Series(data[i]['lon'])

# %%
layout = dict(
        title = 'Chicago schools',
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='d3-bubble-map-populations' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~andrewlai57/0 or inside your plot.ly account where it is named 'd3-bubble-map-populations'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~andrewlai57/0.embed" height="525px" width="100%"></iframe>
