# %% [markdown]
# #  FLASK API
#     ## UNDERSTAND HOW FLASK WORKS
#     ## WHAT DOES THE WEB UI look like?

# %% [markdown]
# # Link the Finance tab to the DEPT ID tab

# %%
# %config InlineBackend.figure_format = 'retina'

import plotly.plotly as py
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

# %% [markdown]
# # Mapping data

# %%
df = pd.read_csv('../data/raw/CPS_School_Locations_SY1516.csv')
df['type'] = 'scattergeo'
df['locationmode'] = 'USA-states'
df['lon'] = df['Long']
df['lat'] = df['Lat']
df['name'] = df['Short_Name']

df_mapping = df

# %% [markdown]
# # Pull in CPS salary data

# %%
# Import datasets to explore
df_2017_12 = pd.read_excel('../data/raw/EmployeePositionRoster_12312017.xls', header=0)
df_2016_12 = pd.read_excel('../data/raw/EmployeePositionRoster_12312016.xls', header=0)
df_2015_12 = pd.read_excel('../data/raw/EmployeePositionRoster_12312015.xls', header=0)

# Make 2015 data have consistent naming
df_2015_12['ClsIndc'] = np.nan
col_renames = [name for name in df_2016_12.columns if name!='ClsIndc'] + ['ClsIndc']
df_2015_12.columns = col_renames
df_2015_12 = df_2015_12[df_2016_12.columns]

# Add year to DF
df_2017_12['year'] = 2017
df_2016_12['year'] = 2016
df_2015_12['year'] = 2015

df = pd.concat([df_2017_12, df_2016_12, df_2015_12])

# Check that rows were all appended
assert(df.shape[0] == df_2017_12.shape[0] + df_2016_12.shape[0] + df_2015_12.shape[0])

df.head()
# Out:
#     Pos #  Dept ID                      Department  FTE ClsIndc  \
# 0  111427    49021       Northside Learning Center  1.0       T
# 1  111427    49021       Northside Learning Center  1.0       T
# 2  111428    11675  Diverse Lrn Related Svc Prv CW  1.0       T
# 3  111435    23231             Telpochcalli School  0.5       T
# 4  111436    23131                   Esmond School  1.0       T
#
#    Annual Salary  FTE Annual Salary  Annual Benefit Cost  JobCode  \
# 0        75996.0            75996.0              27080.0   500629
# 1        90155.0            90155.0              30232.0   500629
# 2        67485.0            67485.0              25185.0   984100
# 3        46236.0            46236.0              10228.0       55
# 4        95009.0            95009.0              31312.0       49
#
#                    Job Title                 Name  year
# 0  Special Education Teacher  McKernin, Kristen F  2017
# 1  Special Education Teacher     Prusaitis, Dan P  2017
# 2       School Social Worker      Gunn, Monique N  2017
# 3          Bilingual Teacher       Ceron, Marisol  2017
# 4            Regular Teacher         Jeff, Lisa Y  2017

# %%
# format df and rename columns to prepare for pivot
temp = df.groupby(['Dept ID', 'Department', 'Job Title', 'year'])['Annual Salary', 'Annual Benefit Cost'].agg(['count','sum','mean']).reset_index()
temp.columns = [' '.join(col).strip().lower().replace(' ', '_') for col in temp.columns.values]
# display(temp.head())

# create a pivot table:
pivot = pd.pivot_table(temp,
               index=['dept_id', 'department'],
               columns='year',
               values='annual_salary_sum',
               aggfunc='sum'
              )
# display(pivot.head())

pivot['2016_delta'] = pivot[2016] - pivot[2015]
pivot['2017_delta'] = pivot[2017] - pivot[2016]


df_funding = pivot[['2016_delta','2017_delta']].reset_index()

# format df and rename columns to prepare for pivot
temp = df.groupby(['Dept ID', 'Department', 'Job Title', 'year'])['Annual Salary', 'Annual Benefit Cost'].agg(['count','sum','mean']).reset_index()
temp.columns = [' '.join(col).strip().lower().replace(' ', '_') for col in temp.columns.values]
# display(temp.head())

# create a pivot table:
pivot = pd.pivot_table(temp,
               index=['dept_id', 'department'],
               columns='year',
               values='annual_salary_count',
               aggfunc='sum'
              )
# display(pivot.head())

pivot['2016_delta_emps'] = pivot[2016] - pivot[2015]
pivot['2017_delta_emps'] = pivot[2017] - pivot[2016]

df_emps = pivot[['2016_delta_emps','2017_delta_emps']].reset_index()

df_deltas = pd.concat([df_funding, df_emps], axis=1)

# %%
df_link = pd.read_csv('../data/raw/Chicago_Public_Schools_-_School_Profile_Information_SY1617.csv')

# %%
df_link = df_link[['School_ID','Legacy_Unit_ID','Finance_ID','Long_Name']]
df_link.head()
# Out:
#    School_ID  Legacy_Unit_ID  Finance_ID  \
# 0     610158            5720       29271
# 1     610282            7040       26301
# 2     609996            4020       23821
# 3     400079            3344       66395
# 4     610089            5020       24621
#
#                                      Long_Name
# 0  Harriet E Sayre Elementary Language Academy
# 1            Ronald E McNair Elementary School
# 2           Charles N Holden Elementary School
# 3   Acero Charter Schools - SPC Daniel Zizumbo
# 4              John B Murphy Elementary School

# %%
df_mapping.set_index('School_ID').sort_values('Short_Name')
# Out:
#                                Short_Name  \
# School_ID
# 400010                        ACE TECH HS
# 609772                             ADDAMS
# 609773                            AGASSIZ
# 400060                     AHS - PASSAGES
# 610513                       AIR FORCE HS
# 610212                        ALBANY PARK
# 609774                          ALCOTT ES
# 610524                          ALCOTT HS
# 609848                           ALDRIDGE
# 400012                         AMANDLA HS
# 609695                        AMUNDSEN HS
# 609951                              ARIEL
# 609777                             ARMOUR
# 609779                        ARMSTRONG G
# 610287                            ASHBURN
# 610268                               ASHE
# 400172     ASPIRA - BUSINESS & FINANCE HS
# 400013          ASPIRA - EARLY COLLEGE HS
# 400017                    ASPIRA - HAUGAN
# 609782                            AUDUBON
# 400018              AUSTIN BUS & ENTRP HS
# 610501                     AUSTIN POLY HS
# 609786                        AVALON PARK
# 610544                             AZUELA
# 610563               BACK OF THE YARDS HS
# 610555                     BANNER WEST HS
# 609788                            BARNARD
# 609789                              BARRY
# 609790                             BARTON
# 609791                               BASS
# ...                                   ...
# 610380                        WILLIAMS HS
# 609977                           WOODLAWN
# 610345                            WOODSON
# 610392                  WORLD LANGUAGE HS
# 610234                              YATES
# 400134                      YCCS - ADDAMS
# 400125              YCCS - ASPIRA PANTOJA
# 400126           YCCS - ASSOCIATION HOUSE
# 400127               YCCS - AUSTIN CAREER
# 400131                      YCCS - CAMPOS
# 400128                 YCCS - CCA ACADEMY
# 400150                     YCCS - CHATHAM
# 400129                     YCCS - HOUSTON
# 400133                 YCCS - INNOVATIONS
# 400135                YCCS - LATINO YOUTH
# 400124                    YCCS - MCKINLEY
# 400136                YCCS - OLIVE HARVEY
# 400123      YCCS - SCHOLASTIC ACHIEVEMENT
District        ES  PK, K, 1, 2, 3, 4, 5, 6, 7, 8
# 610392      Network 7   District        HS                  9, 10, 11, 12
# 610234      Network 5   District        ES  PK, K, 1, 2, 3, 4, 5, 6, 7, 8
# 400134        Options    Charter        HS                     10, 11, 12
# 400125        Options    Charter        HS                     10, 11, 12
# 400126        Options    Charter        HS                         10, 11
# 400127        Options    Charter        HS                     10, 11, 12
# 400131        Options    Charter        HS                     10, 11, 12
# 400128        Options    Charter        HS                     10, 11, 12
# 400150        Options    Charter        HS                     10, 11, 12
# 400129        Options    Charter        HS                     10, 11, 12
# 400133        Options    Charter        HS                     10, 11, 12
# 400135        Options    Charter        HS                     10, 11, 12
# 400124        Options    Charter        HS                     10, 11, 12
# 400136        Options    Charter        HS                         10, 11
# 400123        Options    Charter        HS                     10, 11, 12
# 400139        Options    Charter        HS                         10, 11
# 400141        Options    Charter        HS                     10, 11, 12
# 400142        Options    Charter        HS                     10, 11, 12
# 400143        Options    Charter        HS                         10, 11
# 400144        Options    Charter        HS                     10, 11, 12
# 400145        Options    Charter        HS                     10, 11, 12
# 400130        Options    Charter        HS                     10, 11, 12
# 609748        Options   District        HS                  9, 10, 11, 12
# 610235      Network 3   District        ES  PK, K, 1, 2, 3, 4, 5, 6, 7, 8
# 609755            ISP   District        HS            7, 8, 9, 10, 11, 12
# 400087        Charter    Charter        HS               8, 9, 10, 11, 12
# 609973            ISP   District        ES  PK, K, 1, 2, 3, 4, 5, 6, 7, 8
#
#                          Phone  GeoNetwork         COMMAREA  WARD_15  \
# School_ID
# 400010          1(773)548-8705           9  WASHINGTON PARK        3
# 609772          1(773)535-6210          13        EAST SIDE       10
# 609773          1(773)534-5725           4        LAKE VIEW       44
# 400060          1(773)433-3530           2        EDGEWATER       40
# 610513          1(773)535-1590           6    ARMOUR SQUARE       11
# 610212          1(773)534-5108           1      ALBANY PARK       33
# 609774          1(773)534-5460           4     LINCOLN PARK       43
# 610524          1(773)534-5970           4     NORTH CENTER       32
# 609848          1(773)535-5614          13        RIVERDALE        9
# 400012          1(773)535-7150          11        ENGLEWOOD        6
# 609695          1(773)534-2320           2   LINCOLN SQUARE       40
# 609951          1(773)535-1996           9          KENWOOD        4
# 609777          1(773)535-4530           6       BRIDGEPORT       11
# 609779          1(773)534-2150           2       WEST RIDGE       50
# 610287          1(773)535-7860          10          ASHBURN       18
# 610268          1(773)535-3550          12          CHATHAM        8
# 400172          1(773)252-0970           4         AVONDALE       30
# 400013     1(773)252-0970 x137           4         AVONDALE       30
# 400017          1(773)252-0970           1      ALBANY PARK       35
# 609782          1(773)534-5470           4     NORTH CENTER       47
# 400018          1(773)534-6316           3           AUSTIN       28
# 610501          1(773)534-6300           3           AUSTIN       37
# 609786          1(773)535-6615          12      AVALON PARK        8
# 610544          1(773)535-7395          10        WEST LAWN       13
# 610563          1(773)535-7320           8         NEW CITY       15
# 610555          1(773)854-1188           3           AUSTIN       37
# 609788          1(773)535-2625          10          BEVERLY       19
# 609789          1(773)534-3455           4          HERMOSA       31
# 609790          1(773)535-3260          11   AUBURN GRESHAM       17
# 609791          1(773)535-3275          11        ENGLEWOOD       16
# ...                        ...         ...              ...      ...
()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e8427c7c9571> in <module>()
# ----> 1 df_deltas.sort_values('department').head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3627
#    3628                 raise ValueError('Cannot sort by duplicate column %s' %
# -> 3629                                  str(by))
#    3630             if isinstance(ascending, (tuple, list)):
#    3631                 ascending = ascending[0]
#
# ValueError: Cannot sort by duplicate column department

# %%
columnNumbers = [x for x in range(df_deltas.reset_index().shape[1])]  # list of columns' integer indices

print(columnNumbers)
columnNumbers.remove(0)
columnNumbers.remove(1) #removing column integer index 0
columnNumbers.remove(2) 
print(columnNumbers)
df_deltas = df_deltas.reset_index().iloc[:,np.array(columnNumbers)] #return all columns except 0th column
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# [3, 4, 5, 6, 7, 8]

# %%
df_tmp = pd.merge(df_deltas, df_link, how='inner', left_on='dept_id', right_on='Finance_ID')
df_plot = pd.merge(df_tmp, df_mapping, how='inner', left_on='School_ID', right_on='School_ID')

# %%
df_plot['color'] = ['red' if x < 0 else 'green' for x in df_plot['2017_delta']]

# %%
df_plot['size'] = abs(df_plot['2017_delta'])/abs(df_plot['2017_delta']).max()*7 + 2

# %%
data = df_plot.loc[:,['type','locationmode','lon','lat','name', 'color', 'size']].to_dict(orient='records')
display(data)
# Out:
# [{'color': 'green',
#   'lat': 41.811069,
#   'locationmode': 'USA-states',
#   'lon': -87.704199,
#   'name': 'COLUMBIA EXPLORERS',
#   'size': 3.686794874162158,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.698739,
#   'locationmode': 'USA-states',
#   'lon': -87.532976,
#   'name': 'ADDAMS',
#   'size': 2.0838480405733946,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.934126,
#   'locationmode': 'USA-states',
#   'lon': -87.65622900000001,
#   'name': 'AGASSIZ',
#   'size': 2.4999969225277128,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.935795,
#   'locationmode': 'USA-states',
#   'lon': -87.680562,
#   'name': 'ALCOTT HS',
#   'size': 3.4928387219873085,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.935795,
#   'locationmode': 'USA-states',
#   'lon': -87.680562,
#   'name': 'ALCOTT HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.92985,
#   'locationmode': 'USA-states',
#   'lon': -87.646413,
#   'name': 'ALCOTT ES',
#   'size': 3.4928387219873085,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.92985,
#   'locationmode': 'USA-states',
#   'lon': -87.646413,
#   'name': 'ALCOTT ES',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.833853999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.650653,
#   'name': 'ARMOUR',
#   'size': 2.710287528235808,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 42.007703,
#   'locationmode': 'USA-states',
#   'lon': -87.673168,
#   'name': 'NEW FIELD',
#   'size': 2.038076025875387,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 42.01015,
#   'locationmode': 'USA-states',
#   'lon': -87.684442,
#   'name': 'ARMSTRONG G',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 42.01015,
#   'locationmode': 'USA-states',
#   'lon': -87.684442,
#   'name': 'ARMSTRONG G',
#   'size': 2.4251589514436422,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.945062,
#   'locationmode': 'USA-states',
#   'lon': -87.68104100000001,
#   'name': 'AUDUBON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.945062,
#   'locationmode': 'USA-states',
#   'lon': -87.68104100000001,
#   'name': 'AUDUBON',
#   'size': 2.86545675843689,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.748247,
#   'locationmode': 'USA-states',
#   'lon': -87.591654,
#   'name': 'AVALON PARK',
#   'size': 2.3038865397517094,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.705131,
#   'locationmode': 'USA-states',
#   'lon': -87.658074,
#   'name': 'BARNARD',
#   'size': 2.061794104794086,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.705131,
#   'locationmode': 'USA-states',
#   'lon': -87.658074,
#   'name': 'BARNARD',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.932511,
#   'locationmode': 'USA-states',
#   'lon': -87.739388,
#   'name': 'BARRY',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.932511,
#   'locationmode': 'USA-states',
#   'lon': -87.739388,
#   'name': 'BARRY',
#   'size': 2.5400225270971433,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.754194,
#   'locationmode': 'USA-states',
#   'lon': -87.670927,
#   'name': 'BARTON',
#   'size': 2.513272368607321,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.774246000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.653532,
#   'name': 'BASS',
#   'size': 2.2555940752503525,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.958220000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.702151,
#   'name': 'BATEMAN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.958220000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.702151,
#   'name': 'BATEMAN',
#   'size': 4.238692597448161,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.784942,
#   'locationmode': 'USA-states',
#   'lon': -87.647453,
#   'name': 'NICHOLSON',
#   'size': 3.11497590339199,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.784942,
#   'locationmode': 'USA-states',
#   'lon': -87.647453,
#   'name': 'NICHOLSON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.867813,
#   'locationmode': 'USA-states',
#   'lon': -87.770418,
#   'name': 'CLARK ES',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.867813,
#   'locationmode': 'USA-states',
#   'lon': -87.770418,
#   'name': 'CLARK ES',
#   'size': 2.219575339599067,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.972394,
#   'locationmode': 'USA-states',
#   'lon': -87.757565,
#   'name': 'BEAUBIEN',
#   'size': 2.803522628653729,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.885321000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.705855,
#   'name': 'BEIDLER',
#   'size': 2.430307562580399,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.958938,
#   'locationmode': 'USA-states',
#   'lon': -87.73402,
#   'name': 'BELDING',
#   'size': 2.3094983104677143,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.949529999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.686018,
#   'name': 'BELL',
#   'size': 2.0227863741837004,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.710435,
#   'locationmode': 'USA-states',
#   'lon': -87.61739,
#   'name': 'BENNETT',
#   'size': 2.0688492100128637,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.767755,
#   'locationmode': 'USA-states',
#   'lon': -87.590396,
#   'name': 'SOUTH SHORE',
#   'size': 2.4388706292199838,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.950781,
#   'locationmode': 'USA-states',
#   'lon': -87.664968,
#   'name': 'BLAINE',
#   'size': 3.6419168651636293,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 42.003412,
#   'locationmode': 'USA-states',
#   'lon': -87.697463,
#   'name': 'BOONE',
#   'size': 2.9985882095881724,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.749339,
#   'locationmode': 'USA-states',
#   'lon': -87.669366,
#   'name': 'JOPLIN',
#   'size': 2.865338275753827,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.754365,
#   'locationmode': 'USA-states',
#   'lon': -87.557142,
#   'name': 'BRADWELL',
#   'size': 2.8814465350739518,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.754365,
#   'locationmode': 'USA-states',
#   'lon': -87.557142,
#   'name': 'BRADWELL',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.686659999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.63363199999999,
#   'name': 'HALEY',
#   'size': 2.8763948643142467,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.930966,
#   'locationmode': 'USA-states',
#   'lon': -87.696294,
#   'name': 'BRENTANO',
#   'size': 3.3911482664598607,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.930966,
#   'locationmode': 'USA-states',
#   'lon': -87.696294,
#   'name': 'BRENTANO',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.949114,
#   'locationmode': 'USA-states',
#   'lon': -87.79866899999999,
#   'name': 'BRIDGE',
#   'size': 3.6773485729761,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.699726,
#   'locationmode': 'USA-states',
#   'lon': -87.562084,
#   'name': 'BRIGHT',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.699726,
#   'locationmode': 'USA-states',
#   'lon': -87.562084,
#   'name': 'BRIGHT',
#   'size': 2.1471878058238087,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.940026,
#   'locationmode': 'USA-states',
#   'lon': -87.724783,
#   'name': 'LORCA',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.940026,
#   'locationmode': 'USA-states',
#   'lon': -87.724783,
#   'name': 'LORCA',
#   'size': 2.6608640926688456,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.882996999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.670682,
#   'name': 'BROWN W',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.882996999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.670682,
#   'name': 'BROWN W',
#   'size': 3.0926096041755144,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.77162,
#   'locationmode': 'USA-states',
#   'lon': -87.621746,
#   'name': 'BROWNELL',
#   'size': 2.6736763791692058,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.760847,
#   'locationmode': 'USA-states',
#   'lon': -87.576075,
#   'name': 'BOUCHET',
#   'size': 2.288876938038173,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 42.002959000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.705917,
#   'name': 'WEST RIDGE',
#   'size': 6.592480350339445,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.975753999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.696556,
#   'name': 'BUDLONG',
#   'size': 2.140407365006678,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.917598,
#   'locationmode': 'USA-states',
#   'lon': -87.7827,
#   'name': 'BURBANK',
#   'size': 2.0734484923463263,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.79676,
#   'locationmode': 'USA-states',
#   'lon': -87.616141,
#   'name': 'BURKE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.79676,
#   'locationmode': 'USA-states',
#   'lon': -87.616141,
#   'name': 'BURKE',
#   'size': 2.2422647734057155,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.937937,
#   'locationmode': 'USA-states',
#   'lon': -87.669853,
#   'name': 'BURLEY',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.937937,
#   'locationmode': 'USA-states',
#   'lon': -87.669853,
#   'name': 'BURLEY',
#   'size': 3.4965870832333152,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.714402,
#   'locationmode': 'USA-states',
#   'lon': -87.567131,
#   'name': 'BURNHAM',
#   'size': 2.583672624653015,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.714402,
#   'locationmode': 'USA-states',
#   'lon': -87.567131,
#   'name': 'BURNHAM',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.793479,
#   'locationmode': 'USA-states',
#   'lon': -87.71137,
#   'name': 'HERNANDEZ',
#   'size': 2.986766869164343,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.793479,
#   'locationmode': 'USA-states',
#   'lon': -87.71137,
#   'name': 'HERNANDEZ',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.705342,
#   'locationmode': 'USA-states',
#   'lon': -87.629869,
#   'name': 'HUGHES L',
#   'size': 2.783407500415459,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.84545,
#   'locationmode': 'USA-states',
#   'lon': -87.714927,
#   'name': 'CASTELLANOS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.84545,
#   'locationmode': 'USA-states',
#   'lon': -87.714927,
#   'name': 'CASTELLANOS',
#   'size': 3.1169362532390394,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.912358000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.668661,
#   'name': 'BURR',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.912358000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.668661,
#   'name': 'BURR',
#   'size': 2.5785078567867497,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.828868,
#   'locationmode': 'USA-states',
#   'lon': -87.69245699999999,
#   'name': 'BURROUGHS',
#   'size': 2.0289420881264966,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.897663,
#   'locationmode': 'USA-states',
#   'lon': -87.765606,
#   'name': 'BRUNSON',
#   'size': 2.072866850084015,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.897663,
#   'locationmode': 'USA-states',
#   'lon': -87.765606,
#   'name': 'BRUNSON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.795031,
#   'locationmode': 'USA-states',
#   'lon': -87.79154399999999,
#   'name': 'BYRNE',
#   'size': 2.6081285275526094,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.739226,
#   'locationmode': 'USA-states',
#   'lon': -87.580729,
#   'name': 'CALDWELL',
#   'size': 2.562948926269919,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.739226,
#   'locationmode': 'USA-states',
#   'lon': -87.580729,
#   'name': 'CALDWELL',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.843697999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.71731899999999,
#   'name': 'LITTLE VILLAGE',
#   'size': 2.4722342756553477,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.903791999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.717927,
#   'name': 'CAMERON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.903791999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.717927,
#   'name': 'CAMERON',
#   'size': 2.795902037902149,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.948007000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.829296,
#   'name': 'CANTY',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.948007000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.829296,
#   'name': 'CANTY',
#   'size': 3.478706969243742,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.783367999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.590795,
#   'name': 'CARNEGIE',
#   'size': 2.57977885284143,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.742517,
#   'locationmode': 'USA-states',
#   'lon': -87.696012,
#   'name': 'CARROLL',
#   'size': 2.479801010641899,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.921318,
#   'locationmode': 'USA-states',
#   'lon': -87.765781,
#   'name': 'PRIETO',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.921318,
#   'locationmode': 'USA-states',
#   'lon': -87.765781,
#   'name': 'PRIETO',
#   'size': 3.3490438293603164,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.905109,
#   'locationmode': 'USA-states',
#   'lon': -87.644841,
#   'name': 'SKINNER NORTH',
#   'size': 2.518270183601997,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.793271999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.6878,
#   'name': 'CARSON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.793271999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.6878,
#   'name': 'CARSON',
#   'size': 2.7752052674015673,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.789828,
#   'locationmode': 'USA-states',
#   'lon': -87.62245300000001,
#   'name': 'CARTER',
#   'size': 2.357435326919881,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.653702,
#   'locationmode': 'USA-states',
#   'lon': -87.59951600000001,
#   'name': 'CARVER G',
#   'size': 2.47093096614165,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.653702,
#   'locationmode': 'USA-states',
#   'lon': -87.59951600000001,
#   'name': 'CARVER G',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.657405,
#   'locationmode': 'USA-states',
#   'lon': -87.606474,
#   'name': 'ALDRIDGE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.657405,
#   'locationmode': 'USA-states',
#   'lon': -87.606474,
#   'name': 'ALDRIDGE',
#   'size': 3.0033275169107103,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.687346999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.703215,
#   'name': 'CASSELL',
#   'size': 2.482068338349613,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.95281,
#   'locationmode': 'USA-states',
#   'lon': -87.65098,
#   'name': 'GREELEY',
#   'size': 2.805143687181097,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.866434999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.695259,
#   'name': 'CHALMERS',
#   'size': 2.6866233050821378,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.866434999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.695259,
#   'name': 'CHALMERS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.975894,
#   'locationmode': 'USA-states',
#   'lon': -87.68326400000001,
#   'name': 'CHAPPELL',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.975894,
#   'locationmode': 'USA-states',
#   'lon': -87.68326400000001,
#   'name': 'CHAPPELL',
#   'size': 2.126351010334152,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.934931,
#   'locationmode': 'USA-states',
#   'lon': -87.770127,
#   'name': 'CAMRAS',
#   'size': 3.2685025327596926,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.934931,
#   'locationmode': 'USA-states',
#   'lon': -87.770127,
#   'name': 'CAMRAS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.917993,
#   'locationmode': 'USA-states',
#   'lon': -87.694562,
#   'name': 'CHASE',
#   'size': 2.5635359541087333,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.868576000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.664969,
#   'name': 'STEM',
#   'size': 2.119328218574392,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.896713,
#   'locationmode': 'USA-states',
#   'lon': -87.688937,
#   'name': 'CHOPIN',
#   'size': 2.1671790658025123,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.654558,
#   'locationmode': 'USA-states',
#   'lon': -87.544614,
#   'name': 'CLAY',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.654558,
#   'locationmode': 'USA-states',
#   'lon': -87.544614,
#   'name': 'CLAY',
#   'size': 2.546754497725748,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.952042,
#   'locationmode': 'USA-states',
#   'lon': -87.70644300000001,
#   'name': 'CLEVELAND',
#   'size': 2.6327459977472905,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.992540999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.69836,
#   'name': 'CLINTON',
#   'size': 4.305705325873541,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.693026,
#   'locationmode': 'USA-states',
#   'lon': -87.680897,
#   'name': 'CLISSOLD',
#   'size': 3.9136030430045974,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.741413,
#   'locationmode': 'USA-states',
#   'lon': -87.56597,
#   'name': 'COLES',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.741413,
#   'locationmode': 'USA-states',
#   'lon': -87.56597,
#   'name': 'COLES',
#   'size': 2.289016963027248,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.899566,
#   'locationmode': 'USA-states',
#   'lon': -87.681938,
#   'name': 'COLUMBUS',
#   'size': 2.124126767238461,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.745237,
#   'locationmode': 'USA-states',
#   'lon': -87.659775,
#   'name': 'COOK',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.745237,
#   'locationmode': 'USA-states',
#   'lon': -87.659775,
#   'name': 'COOK',
#   'size': 3.0197966098565283,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 42.017088,
#   'locationmode': 'USA-states',
#   'lon': -87.677763,
#   'name': 'JORDAN',
#   'size': 2.906268657175742,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.955553,
#   'locationmode': 'USA-states',
#   'lon': -87.68376500000001,
#   'name': 'COONLEY',
#   'size': 4.16800152027131,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.856031,
#   'locationmode': 'USA-states',
#   'lon': -87.667227,
#   'name': 'COOPER',
#   'size': 2.2444836309249037,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.856031,
#   'locationmode': 'USA-states',
#   'lon': -87.667227,
#   'name': 'COOPER',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.784681,
#   'locationmode': 'USA-states',
#   'lon': -87.657169,
#   'name': 'LANGFORD',
#   'size': 2.874262176019105,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.784681,
#   'locationmode': 'USA-states',
#   'lon': -87.657169,
#   'name': 'LANGFORD',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.845602,
#   'locationmode': 'USA-states',
#   'lon': -87.731193,
#   'name': 'CORKERY',
#   'size': 3.2086903201186674,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.856029,
#   'locationmode': 'USA-states',
#   'lon': -87.65798000000001,
#   'name': 'PEREZ',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.856029,
#   'locationmode': 'USA-states',
#   'lon': -87.65798000000001,
#   'name': 'PEREZ',
#   'size': 2.1793504686990293,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.973715000000006,
#   'locationmode': 'USA-states',
#   'lon': -87.841041,
#   'name': 'DIRKSEN',
#   'size': 4.943912298194755,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.973715000000006,
#   'locationmode': 'USA-states',
#   'lon': -87.841041,
#   'name': 'DIRKSEN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.923322999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.70541300000001,
#   'name': 'DARWIN',
#   'size': 2.00730284173791,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.821852,
#   'locationmode': 'USA-states',
#   'lon': -87.700202,
#   'name': 'DAVIS N',
#   'size': 3.4109025610724375,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.745078,
#   'locationmode': 'USA-states',
#   'lon': -87.717353,
#   'name': 'DAWES',
#   'size': 2.7329392630069367,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.771079,
#   'locationmode': 'USA-states',
#   'lon': -87.73992,
#   'name': 'AZUELA',
#   'size': 2.1047225350985714,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.771079,
#   'locationmode': 'USA-states',
#   'lon': -87.73992,
#   'name': 'AZUELA',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.76249,
#   'locationmode': 'USA-states',
#   'lon': -87.623345,
#   'name': 'DENEEN',
#   'size': 2.3033695244074326,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.942552,
#   'locationmode': 'USA-states',
#   'lon': -87.813132,
#   'name': 'DEVER',
#   'size': 2.4113611044432544,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.795646000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.642652,
#   'name': 'DEWEY',
#   'size': 2.309956084470459,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.795646000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.642652,
#   'name': 'DEWEY',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.743669,
#   'locationmode': 'USA-states',
#   'lon': -87.60997900000001,
#   'name': 'DIXON',
#   'size': 2.336399265099618,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.831121,
#   'locationmode': 'USA-states',
#   'lon': -87.612275,
#   'name': 'DOOLITTLE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.831121,
#   'locationmode': 'USA-states',
#   'lon': -87.612275,
#   'name': 'DOOLITTLE',
#   'size': 2.3525559946082684,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.780954,
#   'locationmode': 'USA-states',
#   'lon': -87.787604,
#   'name': 'DORE',
#   'size': 3.2194453163949257,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.844043,
#   'locationmode': 'USA-states',
#   'lon': -87.628553,
#   'name': 'DRAKE',
#   'size': 4.776582436250162,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.915914,
#   'locationmode': 'USA-states',
#   'lon': -87.674495,
#   'name': 'DRUMMOND',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.915914,
#   'locationmode': 'USA-states',
#   'lon': -87.674495,
#   'name': 'DRUMMOND',
#   'size': 2.1164361639923435,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.781225,
#   'locationmode': 'USA-states',
#   'lon': -87.675547,
#   'name': 'EARLE',
#   'size': 2.708138683211158,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.77442,
#   'locationmode': 'USA-states',
#   'lon': -87.707953,
#   'name': 'EBERHART',
#   'size': 2.2572043626247145,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 42.004408000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.81116999999999,
#   'name': 'EBINGER',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 42.004408000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.81116999999999,
#   'name': 'EBINGER',
#   'size': 4.309092853493854,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.685418,
#   'locationmode': 'USA-states',
#   'lon': -87.62165300000001,
#   'name': 'CURTIS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.685418,
#   'locationmode': 'USA-states',
#   'lon': -87.62165300000001,
#   'name': 'CURTIS',
#   'size': 2.0045885111804567,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.999437,
#   'locationmode': 'USA-states',
#   'lon': -87.76184,
#   'name': 'EDGEBROOK',
#   'size': 2.174875054625133,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.885529999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.766589,
#   'name': 'ELLINGTON',
#   'size': 4.110822854540195,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.885529999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.766589,
#   'name': 'ELLINGTON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.68942,
#   'locationmode': 'USA-states',
#   'lon': -87.669159,
#   'name': 'ESMOND',
#   'size': 2.107738457940186,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.831555,
#   'locationmode': 'USA-states',
#   'lon': -87.68131,
#   'name': 'EVERETT',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.831555,
#   'locationmode': 'USA-states',
#   'lon': -87.68131,
#   'name': 'EVERETT',
#   'size': 2.7169441007933726,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.935784999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.74933100000001,
#   'name': 'FALCONER',
#   'size': 2.9069903244271282,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.97979,
#   'locationmode': 'USA-states',
#   'lon': -87.766072,
#   'name': 'FARNSWORTH',
#   'size': 3.194192348172905,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.711184,
#   'locationmode': 'USA-states',
#   'lon': -87.640414,
#   'name': 'FERNWOOD',
#   'size': 3.3811634076235144,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 42.009664,
#   'locationmode': 'USA-states',
#   'lon': -87.669985,
#   'name': 'FIELD',
#   'size': 2.578351675068166,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.785183,
#   'locationmode': 'USA-states',
#   'lon': -87.608633,
#   'name': 'FISKE',
#   'size': 2.00347369684436,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.847947,
#   'locationmode': 'USA-states',
#   'lon': -87.69600600000001,
#   'name': 'TELPOCHCALLI',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.847947,
#   'locationmode': 'USA-states',
#   'lon': -87.69600600000001,
#   'name': 'TELPOCHCALLI',
#   'size': 2.168638557034794,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.729673,
#   'locationmode': 'USA-states',
#   'lon': -87.65548100000001,
#   'name': 'FORT DEARBORN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.729673,
#   'locationmode': 'USA-states',
#   'lon': -87.65548100000001,
#   'name': 'FORT DEARBORN',
#   'size': 2.0152788805386805,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.870168,
#   'locationmode': 'USA-states',
#   'lon': -87.702163,
#   'name': 'KELLMAN',
#   'size': 2.0926642293086153,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.870168,
#   'locationmode': 'USA-states',
#   'lon': -87.702163,
#   'name': 'KELLMAN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.738425,
#   'locationmode': 'USA-states',
#   'lon': -87.668099,
#   'name': 'FOSTER PARK',
#   'size': 2.5869847542022884,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.818003000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.611784,
#   'name': 'FULLER',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.818003000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.611784,
#   'name': 'FULLER',
#   'size': 2.523025647654043,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.797579999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.668436,
#   'name': 'FULTON',
#   'size': 2.8446361196767422,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.917617,
#   'locationmode': 'USA-states',
#   'lon': -87.716892,
#   'name': 'FUNSTON',
#   'size': 2.5836403111939976,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.976352,
#   'locationmode': 'USA-states',
#   'lon': -87.796235,
#   'name': 'GARVY',
#   'size': 2.6162230490364435,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.837065,
#   'locationmode': 'USA-states',
#   'lon': -87.71869699999999,
#   'name': 'GARY',
#   'size': 3.4373888263136188,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.725332,
#   'locationmode': 'USA-states',
#   'lon': -87.623719,
#   'name': 'GILLESPIE',
#   'size': 3.460746071606625,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.922831,
#   'locationmode': 'USA-states',
#   'lon': -87.6929,
#   'name': 'GOETHE',
#   'size': 2.2675285127807423,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.670618,
#   'locationmode': 'USA-states',
#   'lon': -87.622546,
#   'name': 'OWENS',
#   'size': 2.936632537499,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.670618,
#   'locationmode': 'USA-states',
#   'lon': -87.622546,
#   'name': 'OWENS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.662481,
#   'locationmode': 'USA-states',
#   'lon': -87.55330699999999,
#   'name': 'GRISSOM',
#   'size': 2.43751884951776,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.975817,
#   'locationmode': 'USA-states',
#   'lon': -87.657912,
#   'name': 'GOUDY',
#   'size': 2.248382788312991,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.975817,
#   'locationmode': 'USA-states',
#   'lon': -87.657912,
#   'name': 'GOUDY',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.813303999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.643344,
#   'name': 'GRAHAM ES',
#   'size': 2.4029326772162416,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.948764000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.757116,
#   'name': 'GRAY',
#   'size': 2.1815262416061945,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.838791,
#   'locationmode': 'USA-states',
#   'lon': -87.71719,
#   'name': 'ORTIZ DE DOMINGUEZ',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.838791,
#   'locationmode': 'USA-states',
#   'lon': -87.71719,
#   'name': 'ORTIZ DE DOMINGUEZ',
#   'size': 2.2946071914372412,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.811173,
#   'locationmode': 'USA-states',
#   'lon': -87.597503,
#   'name': 'ARIEL',
#   'size': 2.585983036972752,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.829669,
#   'locationmode': 'USA-states',
#   'lon': -87.671492,
#   'name': 'GREENE',
#   'size': 4.330511291245822,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.870742,
#   'locationmode': 'USA-states',
#   'lon': -87.718666,
#   'name': 'GREGORY',
#   'size': 2.786358796339039,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.73892,
#   'locationmode': 'USA-states',
#   'lon': -87.645025,
#   'name': 'GRESHAM',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.73892,
#   'locationmode': 'USA-states',
#   'lon': -87.645025,
#   'name': 'GRESHAM',
#   'size': 2.4325910470176217,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.775464,
#   'locationmode': 'USA-states',
#   'lon': -87.758803,
#   'name': 'GRIMES',
#   'size': 2.200316518024755,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.849958,
#   'locationmode': 'USA-states',
#   'lon': -87.633806,
#   'name': 'HAINES',
#   'size': 2.5424244942174297,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.780192,
#   'locationmode': 'USA-states',
#   'lon': -87.776579,
#   'name': 'HALE',
#   'size': 3.2157184974549304,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.94522,
#   'locationmode': 'USA-states',
#   'lon': -87.670865,
#   'name': 'HAMILTON',
#   'size': 3.1288060638513953,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.807241999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.661175,
#   'name': 'HAMLINE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.807241999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.661175,
#   'name': 'HAMLINE',
#   'size': 2.6748558204233372,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.852719,
#   'locationmode': 'USA-states',
#   'lon': -87.69624300000001,
#   'name': 'HAMMOND',
#   'size': 2.8144068787660568,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.849215,
#   'locationmode': 'USA-states',
#   'lon': -87.685668,
#   'name': 'FINKL',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.849215,
#   'locationmode': 'USA-states',
#   'lon': -87.685668,
#   'name': 'FINKL',
#   'size': 3.7520842181066163,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.914815999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.72393100000001,
#   'name': 'MCAULIFFE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.914815999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.72393100000001,
#   'name': 'MCAULIFFE',
#   'size': 2.0591982569196965,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.793447,
#   'locationmode': 'USA-states',
#   'lon': -87.586855,
#   'name': 'HARTE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.793447,
#   'locationmode': 'USA-states',
#   'lon': -87.586855,
#   'name': 'HARTE',
#   'size': 2.460881480387269,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.757341,
#   'locationmode': 'USA-states',
#   'lon': -87.632737,
#   'name': 'HARVARD',
#   'size': 2.7585315225486395,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.757341,
#   'locationmode': 'USA-states',
#   'lon': -87.632737,
#   'name': 'HARVARD',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.964029,
#   'locationmode': 'USA-states',
#   'lon': -87.723128,
#   'name': 'HAUGAN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.964029,
#   'locationmode': 'USA-states',
#   'lon': -87.723128,
#   'name': 'HAUGAN',
#   'size': 2.993385742686387,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.841394,
#   'locationmode': 'USA-states',
#   'lon': -87.734313,
#   'name': 'ZAPATA',
#   'size': 3.257979116273058,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.994541,
#   'locationmode': 'USA-states',
#   'lon': -87.668504,
#   'name': 'HAYT',
#   'size': 3.1922266127493524,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.773365999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.594392,
#   'name': 'WOODLAWN',
#   'size': 3.013517027654166,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.707558,
#   'locationmode': 'USA-states',
#   'lon': -87.60466,
#   'name': 'SMITH',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.707558,
#   'locationmode': 'USA-states',
#   'lon': -87.60466,
#   'name': 'SMITH',
#   'size': 2.187234952699251,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.839595,
#   'locationmode': 'USA-states',
#   'lon': -87.640341,
#   'name': 'HEALY',
#   'size': 2.7641971490296733,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.808175,
#   'locationmode': 'USA-states',
#   'lon': -87.745726,
#   'name': 'HEARST',
#   'size': 3.3836515439678467,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.807112,
#   'locationmode': 'USA-states',
#   'lon': -87.673327,
#   'name': 'HEDGES',
#   'size': 2.860782078032387,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.878665000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.735802,
#   'name': 'HEFFERAN',
#   'size': 2.468146623089659,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.790591,
#   'locationmode': 'USA-states',
#   'lon': -87.671887,
#   'name': 'HENDERSON',
#   'size': 3.228520012802285,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.958989,
#   'locationmode': 'USA-states',
#   'lon': -87.715632,
#   'name': 'HENRY',
#   'size': 2.3138336995525357,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.866875,
#   'locationmode': 'USA-states',
#   'lon': -87.628615,
#   'name': 'SOUTH LOOP',
#   'size': 2.826836789334712,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.862080999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.718994,
#   'name': 'HERZL',
#   'size': 3.873281231727508,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.80977,
#   'locationmode': 'USA-states',
#   'lon': -87.67218199999999,
#   'name': 'LARA',
#   'size': 2.8934025149103535,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.970335,
#   'locationmode': 'USA-states',
#   'lon': -87.710362,
#   'name': 'HIBBARD',
#   'size': 2.9402462593324348,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.983672,
#   'locationmode': 'USA-states',
#   'lon': -87.779123,
#   'name': 'HITCH',
#   'size': 3.047370761551292,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.838027000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.65379200000001,
#   'name': 'HOLDEN',
#   'size': 3.256142634685575,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.793788,
#   'locationmode': 'USA-states',
#   'lon': -87.649795,
#   'name': 'HOLMES',
#   'size': 3.070302546300571,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.893612,
#   'locationmode': 'USA-states',
#   'lon': -87.759398,
#   'name': 'HOWE',
#   'size': 2.5772745597675892,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.733338,
#   'locationmode': 'USA-states',
#   'lon': -87.568228,
#   'name': 'HOYNE',
#   'size': 2.1841059327510757,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.742452,
#   'locationmode': 'USA-states',
#   'lon': -87.653633,
#   'name': 'CUFFE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.742452,
#   'locationmode': 'USA-states',
#   'lon': -87.653633,
#   'name': 'CUFFE',
#   'size': 2.4959361978445385,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.700334999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.611244,
#   'name': 'CULLEN',
#   'size': 2.0596075607339155,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.860518,
#   'locationmode': 'USA-states',
#   'lon': -87.73177700000001,
#   'name': 'HUGHES C',
#   'size': 2.7033347489705855,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.766785,
#   'locationmode': 'USA-states',
#   'lon': -87.719541,
#   'name': 'HURLEY',
#   'size': 2.1649063525182957,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.939246999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.67581,
#   'name': 'JAHN',
#   'size': 2.375299284179946,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.984640999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.700529,
#   'name': 'JAMIESON',
#   'size': 2.3445476423484806,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.902055,
#   'locationmode': 'USA-states',
#   'lon': -87.641056,
#   'name': 'JENNER',
#   'size': 2.4301513808618154,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.902055,
#   'locationmode': 'USA-states',
#   'lon': -87.641056,
#   'name': 'JENNER',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.858065,
#   'locationmode': 'USA-states',
#   'lon': -87.652302,
#   'name': 'JUNGMAN',
#   'size': 4.102679862867835,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.725263,
#   'locationmode': 'USA-states',
#   'lon': -87.677233,
#   'name': 'KELLOGG',
#   'size': 2.5298868721187167,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.776453000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.64089200000001,
#   'name': 'KERSHAW',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.776453000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.64089200000001,
#   'name': 'KERSHAW',
#   'size': 2.1750527786497282,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.904503000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.71423399999999,
#   'name': 'CASALS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.904503000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.71423399999999,
#   'name': 'CASALS',
#   'size': 2.6179841325528863,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 42.003640000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.668222,
#   'name': 'KILMER',
#   'size': 3.865062841984108,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.848488,
#   'locationmode': 'USA-states',
#   'lon': -87.71601700000001,
#   'name': 'CARDENAS',
#   'size': 2.3741952409968547,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.789965,
#   'locationmode': 'USA-states',
#   'lon': -87.779483,
#   'name': 'KINZIE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.789965,
#   'locationmode': 'USA-states',
#   'lon': -87.779483,
#   'name': 'KINZIE',
#   'size': 2.5940721728800833,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.723627,
#   'locationmode': 'USA-states',
#   'lon': -87.639521,
#   'name': 'KIPLING',
#   'size': 2.0299222630500213,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.908885999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.665093,
#   'name': 'LOZANO',
#   'size': 2.4900497627268865,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.908885999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.665093,
#   'name': 'LOZANO',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.719291999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.6525,
#   'name': 'GREEN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.719291999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.6525,
#   'name': 'GREEN',
#   'size': 2.3888763225437155,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.906826,
#   'locationmode': 'USA-states',
#   'lon': -87.75455,
#   'name': 'LEWIS',
#   'size': 2.01425023542663,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.797684999999994,
#   'locationmode': 'USA-states',
#   'lon': -87.659933,
#   'name': 'LIBBY',
#   'size': 2.2871643247102558,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.924525,
#   'locationmode': 'USA-states',
#   'lon': -87.644497,
#   'name': 'LINCOLN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.924525,
#   'locationmode': 'USA-states',
#   'lon': -87.644497,
#   'name': 'LINCOLN',
#   'size': 2.4028949781807216,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.940009,
#   'locationmode': 'USA-states',
#   'lon': -87.702635,
#   'name': 'VON LINNE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.940009,
#   'locationmode': 'USA-states',
#   'lon': -87.702635,
#   'name': 'VON LINNE',
#   'size': 3.273661915049455,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.918814000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.748515,
#   'name': 'LLOYD',
#   'size': 2.584835909177638,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.931762,
#   'locationmode': 'USA-states',
#   'lon': -87.795604,
#   'name': 'LOCKE J',
#   'size': 3.269773528814373,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.912718,
#   'locationmode': 'USA-states',
#   'lon': -87.783919,
#   'name': 'LOVETT',
#   'size': 3.0151111582990193,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.90652,
#   'locationmode': 'USA-states',
#   'lon': -87.710217,
#   'name': 'LOWELL',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.90652,
#   'locationmode': 'USA-states',
#   'lon': -87.710217,
#   'name': 'LOWELL',
#   'size': 2.5971150236042124,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.934191999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.777174,
#   'name': 'LYON',
#   'size': 3.010641129801626,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.759547999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.590712,
#   'name': 'MADISON',
#   'size': 2.6452189929279686,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.908246999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.639827,
#   'name': 'MANIERRE',
#   'size': 3.348241378461387,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.748274,
#   'locationmode': 'USA-states',
#   'lon': -87.574816,
#   'name': 'MANN',
#   'size': 2.913409931618566,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.773881,
#   'locationmode': 'USA-states',
#   'lon': -87.69703,
#   'name': 'MARQUETTE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.773881,
#   'locationmode': 'USA-states',
#   'lon': -87.69703,
#   'name': 'MARQUETTE',
#   'size': 3.41402619544411,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.716588,
#   'locationmode': 'USA-states',
#   'lon': -87.552483,
#   'name': 'MARSH',
#   'size': 2.90441601885875,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.879714,
#   'locationmode': 'USA-states',
#   'lon': -87.70809200000001,
#   'name': 'FARADAY',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.879714,
#   'locationmode': 'USA-states',
#   'lon': -87.70809200000001,
#   'name': 'FARADAY',
#   'size': 2.503497547254587,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.856864,
#   'locationmode': 'USA-states',
#   'lon': -87.731672,
#   'name': 'MASON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.856864,
#   'locationmode': 'USA-states',
#   'lon': -87.731672,
#   'name': 'MASON',
#   'size': 2.117373254303845,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.923204,
#   'locationmode': 'USA-states',
#   'lon': -87.657287,
#   'name': 'MAYER',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.923204,
#   'locationmode': 'USA-states',
#   'lon': -87.657287,
#   'name': 'MAYER',
#   'size': 2.0386091979491723,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.829993,
#   'locationmode': 'USA-states',
#   'lon': -87.641103,
#   'name': 'MCCLELLAN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.829993,
#   'locationmode': 'USA-states',
#   'lon': -87.641103,
#   'name': 'MCCLELLAN',
#   'size': 2.185689292242923,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.842267,
#   'locationmode': 'USA-states',
#   'lon': -87.7063,
#   'name': 'MCCORMICK',
#   'size': 2.3138175428230268,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.775424,
#   'locationmode': 'USA-states',
#   'lon': -87.60935699999999,
#   'name': 'TILL',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.775424,
#   'locationmode': 'USA-states',
#   'lon': -87.60935699999999,
#   'name': 'TILL',
#   'size': 2.299411125677813,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.768143,
#   'locationmode': 'USA-states',
#   'lon': -87.691787,
#   'name': 'MCKAY',
#   'size': 2.694513174658862,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.923955,
#   'locationmode': 'USA-states',
#   'lon': -87.761515,
#   'name': 'HANSON PARK',
#   'size': 2.791808999759957,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.967847,
#   'locationmode': 'USA-states',
#   'lon': -87.676288,
#   'name': 'MCPHERSON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.967847,
#   'locationmode': 'USA-states',
#   'lon': -87.676288,
#   'name': 'MCPHERSON',
#   'size': 2.263693982310689,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.892082,
#   'locationmode': 'USA-states',
#   'lon': -87.683185,
#   'name': 'MITCHELL',
#   'size': 2.605322642194607,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.929989,
#   'locationmode': 'USA-states',
#   'lon': -87.719224,
#   'name': 'MONROE',
#   'size': 3.5213661207230826,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.912504999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.69694100000001,
#   'name': 'MOOS',
#   'size': 2.698536200306516,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.784313,
#   'locationmode': 'USA-states',
#   'lon': -87.688549,
#   'name': 'MORRILL',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.784313,
#   'locationmode': 'USA-states',
#   'lon': -87.688549,
#   'name': 'MORRILL',
#   'size': 2.1697802992534054,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.695734,
#   'locationmode': 'USA-states',
#   'lon': -87.70581,
#   'name': 'MOUNT GREENWOOD',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.695734,
#   'locationmode': 'USA-states',
#   'lon': -87.70581,
#   'name': 'MOUNT GREENWOOD',
#   'size': 2.5751041724369275,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.701952,
#   'locationmode': 'USA-states',
#   'lon': -87.64765200000001,
#   'name': 'MOUNT VERNON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.701952,
#   'locationmode': 'USA-states',
#   'lon': -87.64765200000001,
#   'name': 'MOUNT VERNON',
#   'size': 2.1413282985886712,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.92091,
#   'locationmode': 'USA-states',
#   'lon': -87.721888,
#   'name': 'MOZART',
#   'size': 2.3271576158206697,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.950078000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.716832,
#   'name': 'MURPHY',
#   'size': 2.583952674631165,
#   'type': 'scattergeo'},
#  {'color': 'green',
# ...
#  {'color': 'green',
#   'lat': 41.879118,
#   'locationmode': 'USA-states',
#   'lon': -87.68696,
#   'name': 'PHOENIX MILITARY HS',
#   'size': 2.4525553791138113,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.836169,
#   'locationmode': 'USA-states',
#   'lon': -87.73527800000001,
#   'name': 'INFINITY HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.836169,
#   'locationmode': 'USA-states',
#   'lon': -87.73527800000001,
#   'name': 'INFINITY HS',
#   'size': 2.2982262988471787,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.806118,
#   'locationmode': 'USA-states',
#   'lon': -87.62503000000001,
#   'name': 'WILLIAMS HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.806118,
#   'locationmode': 'USA-states',
#   'lon': -87.62503000000001,
#   'name': 'WILLIAMS HS',
#   'size': 2.4842818102922983,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.833507,
#   'locationmode': 'USA-states',
#   'lon': -87.735299,
#   'name': 'SOCIAL JUSTICE HS',
#   'size': 2.685260754226908,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.833507,
#   'locationmode': 'USA-states',
#   'lon': -87.735299,
#   'name': 'SOCIAL JUSTICE HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.835282,
#   'locationmode': 'USA-states',
#   'lon': -87.735283,
#   'name': 'MULTICULTURAL HS',
#   'size': 2.936217848108278,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.835282,
#   'locationmode': 'USA-states',
#   'lon': -87.735283,
#   'name': 'MULTICULTURAL HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.805203999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.625004,
#   'name': 'BRONZEVILLE HS',
#   'size': 3.6564040659563863,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.805203999999996,
#   'locationmode': 'USA-states',
#   'lon': -87.625004,
#   'name': 'BRONZEVILLE HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.807579,
#   'locationmode': 'USA-states',
#   'lon': -87.74009699999999,
#   'name': 'GLOBAL CITIZENSHIP',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.807579,
#   'locationmode': 'USA-states',
#   'lon': -87.74009699999999,
#   'name': 'GLOBAL CITIZENSHIP',
#   'size': 2.008972370453804,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.87276,
#   'locationmode': 'USA-states',
#   'lon': -87.76333699999999,
#   'name': 'PLATO',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.883362,
#   'locationmode': 'USA-states',
#   'lon': -87.668077,
#   'name': 'HOPE INSTITUTE',
#   'size': 2.004356931390833,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.883362,
#   'locationmode': 'USA-states',
#   'lon': -87.668077,
#   'name': 'HOPE INSTITUTE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.69804,
#   'locationmode': 'USA-states',
#   'lon': -87.631058,
#   'name': 'NKRUMAH',
#   'size': 2.0,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.69804,
#   'locationmode': 'USA-states',
#   'lon': -87.631058,
#   'name': 'NKRUMAH',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.899377,
#   'locationmode': 'USA-states',
#   'lon': -87.69494499999999,
#   'name': 'CHICAGO ARTS HS',
#   'size': 2.025037545161906,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.899377,
#   'locationmode': 'USA-states',
#   'lon': -87.69494499999999,
#   'name': 'CHICAGO ARTS HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.86254,
#   'locationmode': 'USA-states',
#   'lon': -87.660107,
#   'name': 'URBAN PREP - WEST HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.86254,
#   'locationmode': 'USA-states',
#   'lon': -87.660107,
#   'name': 'URBAN PREP - WEST HS',
#   'size': 2.0902514910353234,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.744849,
#   'locationmode': 'USA-states',
#   'lon': -87.55022199999999,
#   'name': 'EPIC HS',
#   'size': 2.0,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.863301,
#   'locationmode': 'USA-states',
#   'lon': -87.659095,
#   'name': 'CHICAGO TECH HS',
#   'size': 2.0700124945374867,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.863301,
#   'locationmode': 'USA-states',
#   'lon': -87.659095,
#   'name': 'CHICAGO TECH HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.691953000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.654248,
#   'name': 'CAMELOT - CHICAGO EXCEL HS',
#   'size': 2.0,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.691953000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.654248,
#   'name': 'CAMELOT - CHICAGO EXCEL HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.763896,
#   'locationmode': 'USA-states',
#   'lon': -87.649124,
#   'name': 'CAMELOT - EXCEL ENGLEWOOD HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.759749,
#   'locationmode': 'USA-states',
#   'lon': -87.556487,
#   'name': 'CAMELOT - EXCEL WOODLAWN HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.765929,
#   'locationmode': 'USA-states',
#   'lon': -87.69073,
#   'name': 'CAMELOT - EXCEL SOUTHWEST HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.809695,
#   'locationmode': 'USA-states',
#   'lon': -87.59934,
#   'name': 'LITTLE BLACK PEARL HS',
#   'size': 2.0,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.795201,
#   'locationmode': 'USA-states',
#   'lon': -87.683963,
#   'name': 'HORIZON - SOUTHWEST',
#   'size': 2.111314480738101,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.795201,
#   'locationmode': 'USA-states',
#   'lon': -87.683963,
#   'name': 'HORIZON - SOUTHWEST',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.939433,
#   'locationmode': 'USA-states',
#   'lon': -87.705206,
#   'name': 'PATHWAYS - AVONDALE HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.891816,
#   'locationmode': 'USA-states',
#   'lon': -87.74661400000001,
#   'name': 'KIPP CHICAGO - CREATE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.891816,
#   'locationmode': 'USA-states',
#   'lon': -87.74661400000001,
#   'name': 'KIPP CHICAGO - CREATE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.891816,
#   'locationmode': 'USA-states',
#   'lon': -87.74661400000001,
#   'name': 'KIPP CHICAGO - CREATE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.858564,
#   'locationmode': 'USA-states',
#   'lon': -87.708987,
#   'name': 'NORTH LAWNDALE - CHRISTIANA HS',
#   'size': 2.449232478411532,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.858564,
#   'locationmode': 'USA-states',
#   'lon': -87.708987,
#   'name': 'NORTH LAWNDALE - CHRISTIANA HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.841331,
#   'locationmode': 'USA-states',
#   'lon': -87.625331,
#   'name': 'YCCS - MCKINLEY',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.841331,
#   'locationmode': 'USA-states',
#   'lon': -87.625331,
#   'name': 'YCCS - MCKINLEY',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.77813,
#   'locationmode': 'USA-states',
#   'lon': -87.598114,
#   'name': 'U OF C - WOODLAWN HS',
#   'size': 2.0046477525219886,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.77813,
#   'locationmode': 'USA-states',
#   'lon': -87.598114,
#   'name': 'U OF C - WOODLAWN HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.813547,
#   'locationmode': 'USA-states',
#   'lon': -87.608426,
#   'name': 'U OF C - WOODSON',
#   'size': 2.0953408608305484,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.813547,
#   'locationmode': 'USA-states',
#   'lon': -87.608426,
#   'name': 'U OF C - WOODSON',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.877248,
#   'locationmode': 'USA-states',
#   'lon': -87.705235,
#   'name': 'LOCKE A',
#   'size': 2.003285201666759,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.844544,
#   'locationmode': 'USA-states',
#   'lon': -87.618724,
#   'name': 'YOUNG WOMENS HS',
#   'size': 2.013463941257209,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.844544,
#   'locationmode': 'USA-states',
#   'lon': -87.618724,
#   'name': 'YOUNG WOMENS HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.937298,
#   'locationmode': 'USA-states',
#   'lon': -87.727096,
#   'name': 'ASPIRA - EARLY COLLEGE HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.937298,
#   'locationmode': 'USA-states',
#   'lon': -87.727096,
#   'name': 'ASPIRA - EARLY COLLEGE HS',
#   'size': 2.0,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.935726,
#   'locationmode': 'USA-states',
#   'lon': -87.718204,
#   'name': 'ASPIRA - BUSINESS & FINANCE HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.935726,
#   'locationmode': 'USA-states',
#   'lon': -87.718204,
#   'name': 'ASPIRA - BUSINESS & FINANCE HS',
#   'size': 2.1553415686491744,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.85837,
#   'locationmode': 'USA-states',
#   'lon': -87.721071,
#   'name': 'KIPP - ASCEND',
#   'size': 2.01684608330102,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 42.013031,
#   'locationmode': 'USA-states',
#   'lon': -87.674818,
#   'name': 'CHICAGO MATH & SCIENCE HS',
#   'size': 2.0,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 42.013031,
#   'locationmode': 'USA-states',
#   'lon': -87.674818,
#   'name': 'CHICAGO MATH & SCIENCE HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.796122,
#   'locationmode': 'USA-states',
#   'lon': -87.625849,
#   'name': 'ACE TECH HS',
#   'size': 2.0963802770956046,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.796122,
#   'locationmode': 'USA-states',
#   'lon': -87.625849,
#   'name': 'ACE TECH HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.827726,
#   'locationmode': 'USA-states',
#   'lon': -87.608501,
#   'name': 'U OF C - DONOGHUE',
#   'size': 2.1140234257190516,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.827726,
#   'locationmode': 'USA-states',
#   'lon': -87.608501,
#   'name': 'U OF C - DONOGHUE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.906771,
#   'locationmode': 'USA-states',
#   'lon': -87.69436400000001,
#   'name': 'ERIE',
#   'size': 2.0076959888226207,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.966406,
#   'locationmode': 'USA-states',
#   'lon': -87.721825,
#   'name': 'ASPIRA - HAUGAN',
#   'size': 2.052827119916785,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.966406,
#   'locationmode': 'USA-states',
#   'lon': -87.721825,
#   'name': 'ASPIRA - HAUGAN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.831118,
#   'locationmode': 'USA-states',
#   'lon': -87.613629,
#   'name': 'URBAN PREP - BRONZEVILLE HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.831118,
#   'locationmode': 'USA-states',
#   'lon': -87.613629,
#   'name': 'URBAN PREP - BRONZEVILLE HS',
#   'size': 2.0,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.907796999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.66407199999999,
#   'name': 'ROWE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.907796999999995,
#   'locationmode': 'USA-states',
#   'lon': -87.66407199999999,
#   'name': 'ROWE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.774572,
#   'locationmode': 'USA-states',
#   'lon': -87.676147,
#   'name': 'MONTESSORI ENGLEWOOD',
#   'size': 2.107749229093192,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.751377000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.64173100000001,
#   'name': 'YCCS - YOUTH DEVELOPMENT',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.883047,
#   'locationmode': 'USA-states',
#   'lon': -87.627734,
#   'name': 'YCCS - INNOVATIONS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.857208,
#   'locationmode': 'USA-states',
#   'lon': -87.644888,
#   'name': 'YCCS - ADDAMS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.857208,
#   'locationmode': 'USA-states',
#   'lon': -87.644888,
#   'name': 'YCCS - ADDAMS',
#   'size': 2.0923572514479507,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.746287,
#   'locationmode': 'USA-states',
#   'lon': -87.578492,
#   'name': 'YCCS - SULLIVAN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.890803000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.702053,
#   'name': 'YCCS - WEST TOWN',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.890803000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.702053,
#   'name': 'YCCS - WEST TOWN',
#   'size': 2.1231412067384334,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.832072,
#   'locationmode': 'USA-states',
#   'lon': -87.62678100000001,
#   'name': 'YCCS - YOUTH CONNECTION',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.730131,
#   'locationmode': 'USA-states',
#   'lon': -87.60698000000001,
#   'name': 'YCCS - CHATHAM',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.881733000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.733778,
#   'name': 'LEGAL PREP HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.679318,
#   'locationmode': 'USA-states',
#   'lon': -87.617968,
#   'name': 'CHICAGO COLLEGIATE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.679318,
#   'locationmode': 'USA-states',
#   'lon': -87.617968,
#   'name': 'CHICAGO COLLEGIATE',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.938988,
#   'locationmode': 'USA-states',
#   'lon': -87.741129,
#   'name': 'INTRINSIC HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.938988,
#   'locationmode': 'USA-states',
#   'lon': -87.741129,
#   'name': 'INTRINSIC HS',
#   'size': 2.014519514251774,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.888259000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.75528100000001,
#   'name': 'MOVING EVEREST',
#   'size': 2.095163136805953,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.888259000000005,
#   'locationmode': 'USA-states',
#   'lon': -87.75528100000001,
#   'name': 'MOVING EVEREST',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.694671,
#   'locationmode': 'USA-states',
#   'lon': -87.65353499999999,
#   'name': 'FOUNDATIONS',
#   'size': 2.0,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.694671,
#   'locationmode': 'USA-states',
#   'lon': -87.65353499999999,
#   'name': 'FOUNDATIONS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'red',
#   'lat': 41.742671,
#   'locationmode': 'USA-states',
#   'lon': -87.559907,
#   'name': 'GREAT LAKES',
#   'size': 2.0134423989511974,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.742671,
#   'locationmode': 'USA-states',
#   'lon': -87.559907,
#   'name': 'GREAT LAKES',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.803515000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.667378,
#   'name': 'PEACE AND EDUCATION HS',
#   'size': 2.0239550442848264,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.803515000000004,
#   'locationmode': 'USA-states',
#   'lon': -87.667378,
#   'name': 'PEACE AND EDUCATION HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.901575,
#   'locationmode': 'USA-states',
#   'lon': -87.635385,
#   'name': 'PAYTON HS',
#   'size': 5.223913806156176,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.901575,
#   'locationmode': 'USA-states',
#   'lon': -87.635385,
#   'name': 'PAYTON HS',
#   'size': nan,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.830555,
#   'locationmode': 'USA-states',
#   'lon': -87.61921600000001,
#   'name': 'CHICAGO MILITARY HS',
#   'size': 2.495171445981129,
#   'type': 'scattergeo'},
#  {'color': 'green',
#   'lat': 41.830555,
#   'locationmode': 'USA-states',
#   'lon': -87.61921600000001,
#   'name': 'CHICAGO MILITARY HS',
#   'size': nan,
#   'type': 'scattergeo'}]

# %%
for i, v in enumerate(data):
    data[i]['marker'] = dict(
            size = 5,  #data[i]['size'],
            color = data[i]['color'],
            line = dict(width=0.5, color='rgb(40,40,40)'),
            sizemode = 'area'
        )
    data[i]['lat'] = pd.Series(data[i]['lat'])
    data[i]['lon'] = pd.Series(data[i]['lon'])
    del data[i]['size']
    del data[i]['color']

# %%
layout = dict(
        title = 'Chicago schools',
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ), #albers usa, Mercator
            showland = True,
            landcolor = 'rgb(217, 217, 217)', 
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)",
            lonaxis = dict( range= [-70, -60] ),
            lataxis = dict( range= [45, 57] )
        )
    )

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='d3-bubble-map-populations' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~andrewlai57/0 or inside your plot.ly account where it is named 'd3-bubble-map-populations'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~andrewlai57/0.embed" height="525px" width="100%"></iframe>
